# %% [markdown]
#   # Identifying Entities in Healthcare Data Assignment

# %% [markdown]
# ### Loading Data

# %%
# importing necessary packages
# !pip install pycrf
# !pip install sklearn-crfsuite

import spacy
import sklearn_crfsuite
from sklearn_crfsuite import metrics
import pandas as pd
from sklearn_crfsuite import CRF, scorers, metrics

model = spacy.load("en_core_web_sm")
# Out:
# Requirement already satisfied: pycrf in c:\users\sush_sneh\anaconda3\lib\site-packages (0.0.1)
# Requirement already satisfied: sklearn-crfsuite in c:\users\sush_sneh\anaconda3\lib\site-packages (0.3.6)
# Requirement already satisfied: python-crfsuite>=0.8.3 in c:\users\sush_sneh\anaconda3\lib\site-packages (from sklearn-crfsuite) (0.9.8)
# Requirement already satisfied: tqdm>=2.0 in c:\users\sush_sneh\anaconda3\lib\site-packages (from sklearn-crfsuite) (4.64.0)
# Requirement already satisfied: tabulate in c:\users\sush_sneh\anaconda3\lib\site-packages (from sklearn-crfsuite) (0.8.9)
# Requirement already satisfied: six in c:\users\sush_sneh\anaconda3\lib\site-packages (from sklearn-crfsuite) (1.16.0)
# Requirement already satisfied: colorama in c:\users\sush_sneh\anaconda3\lib\site-packages (from tqdm>=2.0->sklearn-crfsuite) (0.4.4)

# %%
#defining a function to load all the dataset and convert the word per line to sentences
def process_files(filename):
    input_files= open(filename, 'r')
    input_data=input_files.readlines()
    input_files.close()
    list_data=[]
    sent_data=""
    for word in input_data:
        word=word.strip()
        if word != "":
            if sent_data  =="":
                sent_data=word
            else:
                sent_data=sent_data+" "+word
        else:
            list_data.append(sent_data)
            sent_data=""
    return list_data

# %%
# Passing the filenames to above defined function to get the data
train_sentence=process_files('train_sent')
test_sentence=process_files('test_sent')
train_label=process_files('train_label')
test_label=process_files('test_label')

# %% [markdown]
# ### Printing Sentences

# %%
# printing 5 sentences and respective labels from train data
for i in range(5):
    print("Sentences: ", train_sentence[i])
    print("Labels: ",train_label[i])
    print("\n")
# Out:
# Sentences:  All live births > or = 23 weeks at the University of Vermont in 1995 ( n = 2395 ) were retrospectively analyzed for delivery route , indication for cesarean , gestational age , parity , and practice group ( to reflect risk status )
# Labels:  O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O
#
#
# Sentences:  The total cesarean rate was 14.4 % ( 344 of 2395 ) , and the primary rate was 11.4 % ( 244 of 2144 )
# Labels:  O O O O O O O O O O O O O O O O O O O O O O O O O
#
#
# Sentences:  Abnormal presentation was the most common indication ( 25.6 % , 88 of 344 )
# Labels:  O O O O O O O O O O O O O O O
#
#
# Sentences:  The `` corrected '' cesarean rate ( maternal-fetal medicine and transported patients excluded ) was 12.4 % ( 273 of 2194 ) , and the `` corrected '' primary rate was 9.6 % ( 190 of 1975 )
# Labels:  O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O
#
#
# Sentences:  Arrest of dilation was the most common indication in both `` corrected '' subgroups ( 23.4 and 24.6 % , respectively )
# Labels:  O O O O O O O O O O O O O O O O O O O O O O

# %%
# printing 5 sentences and respective labels from test data
for i in range(5):
    print("Sentences: ", test_sentence[i])
    print("Labels: ",test_label[i])
    print("\n")
# Out:
# Sentences:  Furthermore , when all deliveries were analyzed , regardless of risk status but limited to gestational age > or = 36 weeks , the rates did not change ( 12.6 % , 280 of 2214 ; primary 9.2 % , 183 of 1994 )
# Labels:  O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O
#
#
# Sentences:  As the ambient temperature increases , there is an increase in insensible fluid loss and the potential for dehydration
# Labels:  O O O O O O O O O O O O O O O O O O O
#
#
# Sentences:  The daily high temperature ranged from 71 to 104 degrees F and AFI values ranged from 1.7 to 24.7 cm during the study period
# Labels:  O O O O O O O O O O O O O O O O O O O O O O O O
#
#
# Sentences:  There was a significant correlation between the 2- , 3- , and 4-day mean temperature and AFI , with the 4-day mean being the most significant ( r = 0.31 , p & # 60 ; 0.001 )
# Labels:  O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O
#
#
# Sentences:  Fluctuations in ambient temperature are inversely correlated to changes in AFI
# Labels:  O O O O O O O O O O O

# %% [markdown]
# ### Count the number of sentences in the processed train and test dataset

# %%
# counting the number of sentences in train data
print("The Number of Sentence in Train data",len(train_sentence))
# Out:
# The Number of Sentence in Train data 2599

# %%
# counting the number of sentences in test data
print("The Number of Sentence in Test data",len(test_sentence))
# Out:
# The Number of Sentence in Test data 1056

# %% [markdown]
# ### Count the number of lines of labels in the processed train and test dataset.

# %%
# counting the number of labels in train data
print("The Number of Sentence in Train label",len(train_label))
# Out:
# The Number of Sentence in Train label 2599

# %%
# counting the number of labels in test data
print("The Number of Sentence in Test label",len(test_label))
# Out:
# The Number of Sentence in Test label 1056

# %% [markdown]
# ### Extract those tokens which have NOUN or PROPN as their PoS tag and find their frequency

# %%
train_df = pd.DataFrame(columns=['sentence','word','pos','label'])
test_df = pd.DataFrame(columns=['sentence','word','pos','label'])

# %%
i=0
j=0

for sent,label in zip(train_sentence,train_label):
    i=i+1
    for sentence,lab in zip(sent.split(),label.split()):
        processed_sentence = model(sentence) # Process each sentence by spacy model
        for token in processed_sentence:
            train_df.loc[j,['sentence','word','pos','label']] = [i,token.text,token.pos_,lab]
            j=j+1

# %%
i=0
j=0

for sent,label in zip(test_sentence,test_label):
    i=i+1
    for sentence,lab in zip(sent.split(),label.split()):
        processed_sentence = model(sentence) # Process each sentence by spacy model
        for token in processed_sentence:
            test_df.loc[j,['sentence','word','pos','label']] = [i,token.text,token.pos_,lab]
            j=j+1

# %%
Count_tab = pd.DataFrame()
Count_tab = pd.concat((train_df,test_df),axis=0)

# %%
Count_tab.reset_index(inplace=True,drop=True)

# %% [markdown]
# ### Print the top 25 most common tokens with NOUN or PROPN PoS tags

# %%
Count_tab[(Count_tab['pos'] == 'NOUN') | ((Count_tab['pos'] == 'PROPN'))]['word'].value_counts()[:25]
# Out:
# patients        492
# treatment       281
# cancer          200
# A               182
# therapy         175
# disease         143
# cell            140
# lung            116
# group            94
# chemotherapy     88
# gene             88
# effects          85
# results          79
# women            77
# TO_SEE           75
# cases            71
# risk             71
# surgery          71
# analysis         70
# rate             67
# human            67
# response         66
# survival         65
# children         64
# primary          63
# Name: word, dtype: int64

# %% [markdown]
# ### Defining features for CRF

# %%
# Defining a function to get the features value for a word.
def getFeaturesForOneWord(sentence, pos):
    word = sentence[pos]

    features = [
            'word.lower=' + word.lower(), # serves as word id
            'word[-3:]=' + word[-3:],     # last three characters
            'word[-2:]=' + word[-2:],     # last two characters
            'word.isupper=%s' % word.isupper(),  # is the word in all uppercase
            'word.isdigit=%s' % word.isdigit(),  # is the word a number
            'words.startsWithCapital=%s' % word[0].isupper() # is the word starting with a capital letter
          ]

    if(pos > 0):
        prev_word = sentence[pos-1]
        features.extend([
                'prev_word.lower=' + prev_word.lower(), 
                'prev_word.isupper=%s' % prev_word.isupper(),
                'prev_word.isdigit=%s' % prev_word.isdigit(),
                'prev_words.startsWithCapital=%s' % prev_word[0].isupper()
              ])
    else:
        features.append('BEG') # feature to track begin of sentence 

    if(pos == len(sentence)-1):
        features.append('END') # feature to track end of sentence

    return features

# %% [markdown]
# ### Getting the features

# %% [markdown]
# ### Write a code/function to get the features for a sentence

# %%
# defining a function to get the feature for a sentence
def getFeaturesForOneSentence(sentence):
    sentence_list = sentence.split()
    print("sentence_list: ",sentence_list)
    return [getFeaturesForOneWord(sentence_list, pos) for pos in range(len(sentence_list))]

# %% [markdown]
# ### Write a code/function to get the labels of a sentence

# %%
# Define a function to get the labels for a sentence.
def getLabelsInListForOneSentence(labels):
    return labels.split()

# %% [markdown]
# ### Define input and target variables

# %% [markdown]
# ### Define the features' values for each sentence as input variable for CRF model in test and the train dataset

# %%
X_train = [getFeaturesForOneSentence(sentence) for sentence in train_sentence]
X_test = [getFeaturesForOneSentence(sentence) for sentence in test_sentence]
# Out:
# sentence_list:  ['All', 'live', 'births', '>', 'or', '=', '23', 'weeks', 'at', 'the', 'University', 'of', 'Vermont', 'in', '1995', '(', 'n', '=', '2395', ')', 'were', 'retrospectively', 'analyzed', 'for', 'delivery', 'route', ',', 'indication', 'for', 'cesarean', ',', 'gestational', 'age', ',', 'parity', ',', 'and', 'practice', 'group', '(', 'to', 'reflect', 'risk', 'status', ')']
# sentence_list:  ['The', 'total', 'cesarean', 'rate', 'was', '14.4', '%', '(', '344', 'of', '2395', ')', ',', 'and', 'the', 'primary', 'rate', 'was', '11.4', '%', '(', '244', 'of', '2144', ')']
# sentence_list:  ['Abnormal', 'presentation', 'was', 'the', 'most', 'common', 'indication', '(', '25.6', '%', ',', '88', 'of', '344', ')']
# sentence_list:  ['The', '``', 'corrected', "''", 'cesarean', 'rate', '(', 'maternal-fetal', 'medicine', 'and', 'transported', 'patients', 'excluded', ')', 'was', '12.4', '%', '(', '273', 'of', '2194', ')', ',', 'and', 'the', '``', 'corrected', "''", 'primary', 'rate', 'was', '9.6', '%', '(', '190', 'of', '1975', ')']
# sentence_list:  ['Arrest', 'of', 'dilation', 'was', 'the', 'most', 'common', 'indication', 'in', 'both', '``', 'corrected', "''", 'subgroups', '(', '23.4', 'and', '24.6', '%', ',', 'respectively', ')']
# sentence_list:  ['Cesarean', 'rates', 'at', 'tertiary', 'care', 'hospitals', 'should', 'be', 'compared', 'with', 'rates', 'at', 'community', 'hospitals', 'only', 'after', 'correcting', 'for', 'dissimilar', 'patient', 'groups', 'or', 'gestational', 'age']
# sentence_list:  ['In', 'the', 'third', 'trimester', ',', 'the', 'amniotic', 'fluid', 'index', '(', 'AFI', ')', 'may', 'be', 'affected', 'by', 'maternal', 'fluid', 'status']
# sentence_list:  ['We', 'hypothesize', 'that', 'as', 'temperature', 'increases', 'there', 'would', 'be', 'a', 'concomitant', 'decrease', 'in', 'AFI']
# sentence_list:  ['From', 'June', '11', 'to', 'August', '16', ',', '1993', ',', 'during', 'a', 'period', 'of', 'unusual', 'high', 'heat', ',', '42', 'women', 'with', 'singleton', 'pregnancies', 'between', '27', 'and', '40', 'weeks', "'", 'gestation', 'undergoing', 'serial', 'antenatal', 'testing', 'had', 'AFI', 'determinations', 'recorded', 'at', 'least', 'weekly']
# sentence_list:  ['The', 'daily', 'high', 'ambient', 'temperature', 'in', 'our', 'urban', 'area', 'was', 'subsequently', 'obtained']
# sentence_list:  ['A', '2-', ',', '3-', ',', 'and', '4-day', 'mean', 'temperature', 'prior', 'to', 'the', 'test', 'date', 'was', 'compared', 'to', 'AFI', 'using', 'a', 'Spearman-rank', 'Correlation']
# sentence_list:  ['This', 'relationship', 'should', 'be', 'taken', 'into', 'account', 'when', 'interpreting', 'the', 'AFI', 'as', 'a', 'measure', 'of', 'fetal', 'well-being']
# sentence_list:  ['The', 'study', 'population', 'included', '84', 'women', 'with', 'gestational', 'diabetes', ',', 'ascertained', 'by', 'universal', 'screening', 'of', 'all', 'women', 'attending', 'the', 'antenatal', 'clinic', 'of', 'the', 'Hadassah', 'Medical', 'Center', ',', 'over', 'a', '2-year', 'period']
# sentence_list:  ['The', '60', 'women', '(', '71', '%', ')', ',', 'who', 'initiated', 'treatment', 'before', '34', 'completed', 'weeks', ',', 'composed', 'the', '``', 'early', "''", 'group']
# sentence_list:  ['The', '24', 'women', '(', '29', '%', ')', ',', 'who', 'initiated', 'treatment', 'after', 'the', '34th', 'week', ',', 'composed', 'the', '``', 'late', "''", 'group']
# sentence_list:  ['All', 'patients', 'were', 'managed', 'by', 'an', 'intensified', 'protocol', ',', 'including', 'stringent', 'glycemic', 'control']
# sentence_list:  ['Maternal', 'characteristics', 'were', 'similar', 'in', 'the', 'two', 'groups']
# sentence_list:  ['No', 'significant', 'differences', 'were', 'found', 'between', 'the', 'two', 'groups', 'in', 'the', 'mode', 'of', 'delivery', 'or', 'Apgar', 'scores']
# sentence_list:  ['We', 'conclude', 'that', 'to', 'reduce', 'the', 'rate', 'of', 'macrosomic', 'infants', 'in', 'gestational', 'diabetes', 'cases', ',', 'good', 'glycemic', 'control', 'should', 'be', 'initiated', 'before', '34', 'completed', 'gestational', 'weeks']
# sentence_list:  ['Our', 'aim', 'was', 'to', 'investigate', 'the', 'contribution', 'of', 'certain', 'antenatally', 'detectable', 'markers', 'leading', 'to', 'the', 'diagnosis', 'of', 'trisomic', 'fetuses', 'we', 'observed', 'over', 'a', 'period', 'of', '6', 'years']
# sentence_list:  ['Down', 'syndrome', '(', '12', 'cases', ')', 'and', 'Edward', 'syndrome', '(', '11', 'cases', ')', 'were', 'the', 'most', 'common', 'trisomies', ',', 'while', '4', 'cases', 'of', 'Patau', 'syndrome', 'were', 'also', 'diagnosed']
# sentence_list:  ['Down', 'syndrome', 'fetuses', '(', '41.7', '%', ')', 'had', 'prenatally', 'detected', 'sonographic', 'anomalies', ',', '63.6', '%', 'for', 'Edward', 'syndrome', ',', 'and', 'all', 'fetuses', 'with', 'Patau', 'syndrome', '(', '4', 'of', '4', ')', 'showed', 'abnormal', 'sonographic', 'signs']
# sentence_list:  ['Trisomy', '21', 'presented', 'with', 'the', 'following', 'features', ':', 'hydramnios', ',', 'complex', 'malformations', ',', 'pyelectasis', ',', 'and', 'duodenal', 'atresia']
# sentence_list:  ['Signs', 'observed', 'in', 'fetuses', 'with', 'trisomy', '13', 'were', ':', 'hydrocephalus', ',', 'intrauterine', 'growth', 'retardation', ',', 'oligoanhydramnios', ',', 'complex', 'malformations', ',', 'severe', 'fetal', 'bradycardia', 'and', 'hydronephrosis']
# sentence_list:  ['Fifty-three', 'triplet', 'pregnancies', 'between', '1986', 'and', '1993', 'at', 'The', 'New', 'York', 'Hospital-Cornell', 'Medical', 'Center', 'were', 'reviewed']
# sentence_list:  ['Severe', 'preeclampsia', 'was', 'defined', 'by', 'standard', 'criteria']
# sentence_list:  ['Student', "'s", 't-test', ',', 'Fisher', 'exact', 'test', ',', 'and', 'Chi-square', 'were', 'used', 'for', 'statistical', 'analysis']
# sentence_list:  ['The', 'rate', 'of', 'overall', 'preeclampsia', 'was', 'not', 'significantly', 'different', 'in', 'the', 'triplet', '18', 'of', '53', '(', '33.96', '%', ')', 'or', 'twin', '12', 'of', '53', '(', '22.6', '%', ')', 'groups']
# sentence_list:  ['In', 'this', 'retrospective', ',', 'case-controlled', 'study', ',', 'the', 'rate', 'of', 'severe', 'pre-eclampsia', 'was', 'significantly', 'increased', 'in', 'triplet', 'gestations', 'as', 'compared', 'to', 'twins', 'although', 'the', 'overall', 'rate', 'of', 'preeclampsia', 'was', 'not']
# sentence_list:  ['This', 'information', 'may', 'be', 'useful', 'in', 'counseling', 'patients', 'with', 'high', 'order', 'multifetal', 'gestations']
# sentence_list:  ['The', 'survey', 'indicated', 'a', 'variety', 'of', 'thermal', 'care', 'styles']
# sentence_list:  ['Two', 'NICUs', 'preferred', 'to', 'admit', 'infants', 'to', 'incubators', ',', 'the', 'other', 'three', 'favoring', 'radiant', 'warmers']
# sentence_list:  ['These', 'three', 'NICUs', 'moved', 'infants', 'from', 'radiant', 'warmers', 'into', 'incubators', 'at', 'significantly', 'different', 'mean', 'ages']
# sentence_list:  ['The', 'audit', 'demonstrated', 'inconsistent', 'use', 'of', 'plastic', 'covers', ',', 'warming', 'mattresses', ',', 'and', 'added', 'humidity', 'under', 'radiant', 'warmers', ',', 'and', 'discrepancies', 'between', 'survey', 'responses', 'and', 'actual', 'use', 'within', 'NICUs']
# sentence_list:  ['Inter-NICU', 'variability', 'of', 'thermal', 'equipment', 'use', 'may', 'complicate', 'fluid', 'management']
# sentence_list:  ['This', 'report', 'describes', 'a', 'full-term', 'newborn', 'with', 'massive', 'fetomaternal', 'hemorrhage']
# sentence_list:  ['Fetal', 'movements', 'were', 'decreased', '48', 'hr', 'prior', 'to', 'delivery']
# sentence_list:  ['On', 'the', 'day', 'of', 'delivery', ',', 'they', 'were', 'absent']
# sentence_list:  ['The', 'nonstress', 'test', 'was', 'abnormal', 'with', 'low', 'biophysical', 'profile', 'and', 'decreased', 'beat-to-beat', 'variability']
# sentence_list:  ['Omphalocele-Exstrophy-Imperforate', 'anus-Spinal', 'defects', '(', 'OEIS', 'complex', ')', ',', 'a', 'combination', 'of', 'omphalocele', ',', 'exstrophy', 'of', 'the', 'bladder', ',', 'an', 'imperforate', 'anus', 'and', 'spinal', 'defects', ',', 'arises', 'from', 'a', 'single', 'localized', 'defect', 'in', 'the', 'early', 'development', 'of', 'the', 'mesoderm', 'that', 'will', 'later', 'contribute', 'to', 'infraumbilical', 'mesenchyme', ',', 'cloacal', 'septum', ',', 'and', 'caudal', 'vertebrae']
# sentence_list:  ['In', 'this', 'report', ',', 'we', 'document', 'the', 'perinatal', 'features', 'of', 'two', 'cases', 'of', 'OEIS', 'complex', 'associated', 'with', 'meningomyeloceles', 'and', 'severe', 'lower', 'limb', 'defects', ',', 'and', 'discuss', 'the', 'prenatal', 'diagnosis', ',', 'inheritance', ',', 'and', 'differential', 'diagnosis', 'of', 'this', 'association', 'of', 'malformations']
# sentence_list:  ['Although', 'long-term', 'survival', 'can', 'be', 'achieved', 'by', 'successful', 'corrective', 'surgery', ',', 'the', 'associated', 'structural', 'defects', 'such', 'as', 'large', 'meningomyelocele', 'and', 'severe', 'limb', 'aplasia', 'or', 'hypoplasia', ',', 'as', 'seen', 'in', 'our', 'patient', ',', 'can', 'influence', 'the', 'patient', "'s", 'quality', 'of', 'life', '.']
# sentence_list:  ['We', 'would', 'like', 'to', 'emphasize', 'that', 'an', 'accurate', 'prenatal', 'diagnosis', 'of', 'OEIS', 'complex', 'and', 'associated', 'malformations', 'is', 'important', 'for', 'the', 'detailed', 'counseling', 'of', 'the', 'family', 'as', 'well', 'as', 'appropriate', 'perinatal', 'management', 'by', 'the', 'obstetricians', ',', 'pediatric', 'surgeons', ',', 'urologists', ',', 'neurosurgeons', ',', 'and', 'neonatologists']
# sentence_list:  ['Nonimmune', 'hydrops', 'fetails', 'diagnosed', 'at', '21', 'weeks', "'", 'gestation', 'with', 'profound', 'ascites', ',', 'hydrothorax', ',', 'and', 'pericardial', 'effusion', 'receded', 'gradually', 'with', 'regression', 'of', 'a', 'subchorial', 'placental', 'lucencies', 'immediately', 'below', 'the', 'umbilical', 'cord', 'insertion']
# sentence_list:  ['Careful', 'inspection', 'of', 'the', 'delivered', 'placenta', 'revealed', 'that', 'there', 'was', 'a', 'yellowish', 'lesion', 'of', 'fibrin', 'deposits', 'below', 'the', 'cord', 'insertion', 'site', ',', 'which', 'resulted', 'from', 'the', 'absorption', 'of', 'hematoma']
# sentence_list:  ['The', 'mitochondrial', 'diseases', 'are', 'uncommon', 'multisystem', 'disorders', 'characterized', 'by', 'the', 'presence', 'of', 'functionally', 'and/or', 'structurally', 'abnormal', 'mitochondria']
# sentence_list:  ['As', 'there', 'have', 'been', 'few', 'reports', 'of', 'the', 'obstetrical', 'care', 'of', 'affected', 'patients', ',', 'we', 'wish', 'to', 'document', 'two', 'pregnancies', 'in', 'a', 'woman', 'with', 'a', 'Chronic', 'Progressive', 'External', 'Ophthalmoplegia', '(', 'Kearns-Sayre-like', 'syndrome', ')']
# sentence_list:  ['Both', 'pregnancies', 'were', 'complicated', 'by', 'preterm', 'labor', 'and', 'hypertension']
# sentence_list:  ['CONTEXT', ':', 'Four', 'genetic', 'loci', 'have', 'been', 'identified', 'as', 'contributing', 'to', 'Alzheimer', 'disease', '(', 'AD', ')', ',', 'including', 'the', 'amyloid', 'precursor', 'protein', 'gene', ',', 'the', 'presenilin', '1', 'gene', ',', 'the', 'presenilin', '2', 'gene', ',', 'and', 'the', 'apolipoprotein', 'E', 'gene', ',', 'but', 'do', 'not', 'account', 'for', 'all', 'the', 'genetic', 'risk', 'for', 'AD']
# sentence_list:  ['OBJECTIVE', ':', 'To', 'identify', 'additional', 'genetic', 'risk', 'factors', 'for', 'late-onset', 'AD']
# sentence_list:  ['DESIGN', ':', 'A', 'complete', 'genomic', 'screen', 'was', 'performed', '(', 'N=280', 'markers', ')']
# sentence_list:  ['Critical', 'values', 'for', 'chromosomal', 'regional', 'follow-up', 'were', 'a', 'P', 'value', 'of', '.05', 'or', 'less', 'for', 'affected', 'relative', 'pair', 'analysis', 'or', 'sibpair', 'analysis', ',', 'a', 'parametric', 'lod', 'score', 'of', '1.0', 'or', 'greater', ',', 'or', 'both']
# sentence_list:  ['Regional', 'follow-up', 'included', 'analysis', 'of', 'additional', 'markers', 'and', 'a', 'second', 'data', 'set']
# sentence_list:  ['PATIENTS', ':', '>', 'From', 'a', 'series', 'of', 'multiplex', 'families', 'affected', 'with', 'late-onset', '(', '>', 'or', '=60', 'years', ')', 'AD', 'ascertained', 'during', 'the', 'last', '14', 'years', '(', 'National', 'Insititute', 'of', 'Neurological', 'Disorders', 'and', 'Stroke-Alzheimer', "'s", 'Disease', 'and', 'Related', 'Disorders', 'Association', 'diagnostic', 'criteria', ')', 'and', 'for', 'which', 'DNA', 'has', 'been', 'obtained', ',', 'a', 'subset', 'of', '16', 'families', '(', '135', 'total', 'family', 'members', ',', '52', 'of', 'whom', 'were', 'patients', 'with', 'AD', ')', 'was', 'used', 'for', 'the', 'genomic', 'screen']
# sentence_list:  ['A', 'second', 'subset', 'of', '38', 'families', '(', '216', 'total', 'family', 'members', ',', '89', 'of', 'whom', 'were', 'patients', 'with', 'AD', ')', 'was', 'used', 'for', 'the', 'follow-up', 'analysis']
# sentence_list:  ['MAIN', 'OUTCOME', 'MEASURES', ':', 'Linkage', 'analysis', 'results', 'generated', 'using', 'both', 'genetic', 'model-dependent', '(', 'lod', 'score', ')', 'and', 'model-independent', 'methods']
# sentence_list:  ['RESULTS', ':', 'Fifteen', 'chromosomal', 'regions', 'warranted', 'initial', 'follow-up']
# sentence_list:  ['Follow-up', 'analyses', 'revealed', '4', 'regions', 'of', 'continued', 'interest', 'on', 'chromosomes', '4', ',', '6', ',', '12', ',', 'and', '20', ',', 'with', 'the', 'strongest', 'results', 'observed', 'forchromosome', '12']
# sentence_list:  ['Peak', '2-point', 'affecteds-only', 'lod', 'scores', '(', 'n=54', ')', 'were', '1.3', ',', '1.6', ',', '2.7', ',', 'and', '2.2', 'and', 'affected', 'relative', 'pairs', 'P', 'values', '(', 'n=54', ')', 'were', '.04', ',', '.03', ',', '.14', ',', 'and', '.04', 'for', 'D12S373', ',', 'D12S1057', ',', 'D12S1042', ',', 'and', 'D12S390', ',', 'respectively']
# sentence_list:  ['Analysis', 'of', 'these', '27', 'families', 'resulted', 'in', 'MLSs', 'of', '1.0', ',', '2.4', ',', '3.7', ',', 'and', '3.3', 'and', 'a', 'peak', 'multipoint', 'MLS', 'of', '3.9']
# sentence_list:  ['Additional', 'analyses', 'are', 'necessary', 'to', 'identify', 'the', 'chromosome', '12', 'susceptibility', 'gene', 'for', 'AD', 'and', 'to', 'follow', 'up', 'the', 'regions', 'of', 'interest', 'on', 'chromosomes', '4', ',', '6', ',', 'and', '20']
# sentence_list:  ['However', ',', 'knowledge', 'regarding', 'all', 'possible', 'mutations', 'and', 'the', 'relationship', 'between', 'risk', 'factors', 'and', 'mutations', 'is', 'incomplete']
# sentence_list:  ['OBJECTIVES', ':', 'To', 'identify', 'BRCA1', 'mutations', 'and', 'to', 'determine', 'factors', 'that', 'best', 'predict', 'presence', 'of', 'a', 'deleterious', 'BRCA1', 'mutation', 'in', 'patients', 'with', 'breast', 'and/or', 'ovarian', 'cancer']
# sentence_list:  ['No', 'participant', 'was', 'from', 'a', 'family', 'in', 'which', 'genetic', 'markers', 'showed', 'linkage', 'to', 'the', 'BRCA1', 'locus']
# sentence_list:  ['MAJOR', 'OUTCOME', 'MEASURES', ':', 'Sequence', 'variants', 'detected', 'in', 'this', 'sample', 'are', 'presented', 'along', 'with', 'analyses', 'designed', 'to', 'determine', 'predictive', 'characteristics', 'of', 'those', 'testing', 'positive', 'for', 'BRCA1', 'mutations']
# sentence_list:  ['Fifty', 'new', 'genetic', 'alterations', 'were', 'found', 'including', '24', 'deleterious', 'mutations', ',', '24', 'variants', 'of', 'unknown', 'significance', ',', 'and', '2', 'rare', 'polymorphisms']
# sentence_list:  ['A', 'bias', 'in', 'prior', 'reports', 'for', 'mutations', 'in', 'exon', '11', 'was', 'revealed']
# sentence_list:  ['Characteristics', 'of', 'a', 'patient', "'s", 'specific', 'diagnosis', '(', 'unilateral', 'or', 'bilateral', 'breast', 'cancer', ',', 'with', 'or', 'without', 'ovarian', 'cancer', ')', ',', 'early', 'age', 'at', 'diagnosis', ',', 'Ashkenazi', 'Jewish', 'ethnicity', ',', 'and', 'family', 'history', 'of', 'cancer', 'were', 'positively', 'associated', 'with', 'the', 'probability', 'of', 'her', 'carrying', 'a', 'deleterious', 'BRCA1', 'mutation']
# sentence_list:  ['OBJECTIVE', ':', 'To', 'investigate', 'phenotypic', 'characteristics', 'of', 'families', 'potentially', 'linked', 'to', 'the', 'hereditary', 'prostate', 'cancer', '1', '(', 'HPC1', ')', 'locus', 'on', 'chromosome', '1q24-25']
# sentence_list:  ['Prostate', 'cancer', 'cases', 'from', 'the', 'National', 'Cancer', 'Data', 'Base', 'were', 'used', 'as', 'a', 'reference', 'population', 'for', 'comparison']
# sentence_list:  ['MAIN', 'OUTCOME', 'MEASURES', ':', 'The', 'families', 'were', 'divided', 'into', '2', 'groups', ':', 'either', 'potentially', 'linked', '(', '33', 'families', 'with', '133', 'men', 'with', 'prostate', 'cancer', ')', ',', 'and', 'thus', 'likely', 'to', 'be', 'carrying', 'an', 'altered', 'HPC1', 'gene', ',', 'or', 'potentially', 'unlinked', '(', '41', 'families', 'with', '172', 'men', 'with', 'prostate', 'cancer', ')', ',', 'on', 'the', 'basis', 'of', 'haplotype', 'analysis', 'in', 'the', 'region', 'of', 'HPC1']
# sentence_list:  ['The', 'age', 'at', 'diagnosis', 'of', 'prostate', 'cancer', ',', 'serum', 'prostate-specific', 'antigen', 'levels', ',', 'digital', 'rectal', 'examination', 'status', ',', 'stage', ',', 'grade', ',', 'primary', 'treatment', 'of', 'prostate', 'cancers', ',', 'and', 'occurrence', 'of', 'other', 'cancers', 'were', 'compared', 'between', 'the', 'groups']
# sentence_list:  ['RESULTS', ':', 'The', 'mean', 'age', 'at', 'diagnosis', 'of', 'prostate', 'cancer', 'for', 'men', 'in', 'potentially', 'linked', 'families', 'was', 'significantly', 'lower', 'than', 'for', 'men', 'in', 'potentially', 'unlinked', 'families', '(', '63.7', 'vs', '65.9', 'years', ',', 'respectively', ',', 'P=.01', ';', 'mean', 'age', 'at', 'diagnosis', 'in', 'the', 'reference', 'population', 'was', '71.6', 'years', ')']
# sentence_list:  ['Higher-grade', 'cancers', '(', 'grade', '3', ')', 'were', 'more', 'common', 'in', 'potentially', 'linked', 'families', ',', 'and', 'advanced-stage', 'disease', 'was', 'found', 'in', '41', '%', 'of', 'the', 'case', 'patients', 'in', 'potentially', 'linked', 'families', 'compared', 'with', '31', '%', 'in', 'both', 'the', 'potentially', 'unlinked', 'families', 'and', 'the', 'reference', 'groups', '(', 'P=.03', 'for', 'the', 'latter', 'comparison', ')']
# sentence_list:  ['In', 'the', 'other', 'clinical', 'parameters', ',', 'we', 'found', 'no', 'significant', 'differences', 'between', 'the', 'groups']
# sentence_list:  ['A', 'modest', 'excess', 'of', 'breast', 'cancer', 'and', 'colon', 'cancer', 'was', 'found', 'in', 'potentially', 'linked', 'families', 'in', 'comparison', 'with', 'potentially', 'unlinked', 'families', ',', 'but', 'this', 'difference', 'was', 'not', 'statistically', 'significant']
# sentence_list:  ['However', ',', '3', 'characteristics', 'were', 'observed', ':', 'younger', 'age', 'at', 'diagnosis', ',', 'higher-grade', 'tumors', ',', 'and', 'more', 'advanced-stage', 'disease']
# sentence_list:  ['Our', 'study', 'shows', 'that', 'a', 'significant', 'fraction', 'of', 'hereditary', 'prostate', 'cancers', 'are', 'diagnosed', 'in', 'advanced', 'stages', ',', 'emphasizing', 'the', 'clinical', 'importance', 'of', 'early', 'detection', 'in', 'men', 'potentially', 'carrying', 'prostate', 'cancer', 'susceptibility', 'genes']
# sentence_list:  ['These', 'findings', 'support', 'the', 'current', 'recommendations', 'to', 'screen', 'men', 'with', 'a', 'positive', 'family', 'history', 'of', 'prostate', 'cancer', 'beginning', 'at', 'age', '40', 'years']
# sentence_list:  ['CONTEXT', ':', 'Susceptibility', 'to', 'multiple', 'sclerosis', '(', 'MS', ')', 'involves', 'a', 'genetically', 'complex', 'autoimmune', 'component']
# sentence_list:  ['The', '3', 'regions', 'include', 'HLA', 'on', 'chromosome', '6p21.3', ',', 'APOE', 'on', 'chromosome', '19ql', '3.2', ',', 'and', 'MBP', '(', 'myelin', 'basic', 'protein', ')', 'on', 'chromosome', '18q23']
# sentence_list:  ['SUBJECTS', ':', 'A', 'total', 'of', '120', 'Caucasian', 'patients', 'with', 'MS', 'and', '107', 'unrelated', 'control', 'individuals', 'from', 'California', ',', 'and', '32', 'patients', 'and', '32', 'unrelated', 'control', 'individuals', 'from', 'Beijing', ',', 'China']
# sentence_list:  ['All', 'patients', 'with', 'MS', 'were', 'diagnosed', 'as', 'having', 'clinically', 'definite', 'disease', 'according', 'to', 'published', 'criteria']
# sentence_list:  ['MAIN', 'OUTCOME', 'MEASURES', ':', 'Chi2', 'Testing', 'of', 'loci', 'and', 'individual', 'alleles', 'and', 'haplotypes']
# sentence_list:  ['Haplotype', 'frequencies', 'were', 'estimated', 'with', 'standard', 'maximum', 'likelihood', 'methods']
# sentence_list:  ['RESULTS', ':', 'The', 'HLA', 'effect', 'is', 'due', 'to', 'the', 'class', 'II', 'DR2', 'haplotype', ',', 'DRB1*1501-DQA1*0102-DRB1*0602', ';', 'contributions', 'to', 'MS', 'susceptibility', 'from', 'additional', 'DRB1-DQB1', 'alleles', 'or', 'other', 'HLA', 'region', 'loci', 'were', 'not', 'observed']
# sentence_list:  ['The', 'distribution', 'of', 'haplotypes', 'from', '5', 'loci', 'within', 'the', 'chromosome', '19q13.2', 'region', ',', 'including', 'D19S178', ',', 'D19S574', ',', 'APOE', ',', 'APOC2', ',', 'and', 'D19S219', ',', 'differed', 'between', 'patient', 'and', 'control', 'samples']
# sentence_list:  ['The', 'APOE', 'variation', ',', 'prominent', 'in', 'other', 'neurological', 'diseases', ',', 'showed', 'no', 'influence', 'on', 'MS', 'susceptibility', ',', 'despite', 'its', 'location', 'within', 'the', 'chromosome', '19q13.2', 'region']
# sentence_list:  ['<', 'TO_SEE', '>', 'OBJECTIVE', ':', 'To', 'examine', 'long-term', 'risk', 'of', 'new', 'primary', 'cancers', 'in', 'survivors', 'of', 'childhood', 'retinoblastoma', 'and', 'quantify', 'the', 'role', 'of', 'radiotherapy', 'in', 'sarcoma', 'development']
# sentence_list:  ['DESIGN', ':', 'Cohort', 'incidence', 'study', 'of', 'patients', 'with', 'retinoblastoma', 'followed', 'for', 'a', 'median', 'of', '20', 'years', ',', 'and', 'nested', 'case-control', 'study', 'of', 'a', 'radiation', 'dose-response', 'relationship', 'for', 'bone', 'and', 'soft', 'tissue', 'sarcomas']
# sentence_list:  ['SETTING/PARTICIPANTS', ':', 'A', 'total', 'of', '1604', 'patients', 'with', 'retinoblastoma', 'who', 'survived', 'at', 'least', '1', 'year', 'after', 'diagnosis', ',', 'identified', 'from', 'hospital', 'records', 'in', 'Massachusetts', 'and', 'New', 'York', 'during', '1914', 'to', '1984']
# sentence_list:  ['RESULTS', ':', 'Incidence', 'of', 'subsequent', 'cancers', 'was', 'statistically', 'significantly', 'elevated', 'only', 'in', 'the', '961', 'patients', 'with', 'hereditary', 'retinoblastoma', ',', 'in', 'whom', '190', 'cancers', 'were', 'diagnosed', ',', 'vs', '6.3', 'expected', 'in', 'the', 'general', 'population', '(', 'relative', 'risk', '(', 'RR', ')', ',', '30', '(', '95', '%', 'confidence', 'interval', ',', '26-47', ')', ')']
# sentence_list:  ['Cumulative', 'incidence', '(', '+/-SE', ')', 'of', 'a', 'second', 'cancer', 'at', '50', 'years', 'after', 'diagnosis', 'was', '51.0', '%', '(', '+/-6.2', '%', ')', 'for', 'hereditary', 'retinoblastoma', ',', 'and', '5.0', '%', '(', '+/-3.0', '%', ')', 'for', 'nonhereditary', 'retinoblastoma']
# sentence_list:  ['All', '114', 'sarcomas', 'of', 'diverse', 'histologic', 'types', 'occurred', 'in', 'patients', 'with', 'hereditary', 'retinoblastoma']
# sentence_list:  ['For', 'soft', 'tissue', 'sarcomas', ',', 'the', 'RRs', 'showed', 'a', 'stepwise', 'increase', 'at', 'all', 'dose', 'categories', ',', 'and', 'were', 'statistically', 'significant', 'at', '10', 'to', '29.9', 'Gy', 'and', '30', 'to', '59.9', 'Gy']
# sentence_list:  ['<', 'TO_SEE', '>', 'CONCLUSIONS', ':', 'Genetic', 'predisposition', 'has', 'a', 'substantial', 'impact', 'on', 'risk', 'of', 'subsequent', 'cancers', 'in', 'retinoblastoma', 'patients', ',', 'which', 'is', 'further', 'increased', 'by', 'radiation', 'treatment']
# sentence_list:  ['A', 'radiation', 'dose-response', 'relationship', 'is', 'demonstrated', 'for', 'all', 'sarcomas', 'and', ',', 'for', 'the', 'first', 'time', 'in', 'humans', ',', 'for', 'soft', 'tissue', 'sarcomas']
# sentence_list:  ['Retinoblastoma', 'patients', 'should', 'be', 'examined', 'for', 'new', 'cancers', 'and', 'followed', 'into', 'later', 'life', 'to', 'determine', 'whether', 'their', 'extraordinary', 'cancer', 'risk', 'extends', 'to', 'common', 'cancers', 'of', 'adulthood']
# sentence_list:  ['The', 'objective', 'of', 'this', 'study', 'was', 'to', 'determine', 'the', 'rate', 'of', 'recent', 'cocaine', 'use', 'among', 'a', 'metropolitan', 'population', 'of', 'predominantly', 'Hispanic', 'and', 'African-American', 'women', 'with', 'preterm', 'premature', 'rupture', 'of', 'the', 'membranes', '(', 'PROM', ')', 'and', 'to', 'ascertain', 'the', 'impact', 'of', 'cocaine', 'on', 'the', 'latency', 'period', 'between', 'rupture', 'of', 'membranes', 'and', 'delivery']
# sentence_list:  ['Urine', 'toxicology', 'screens', 'were', 'prospectively', 'obtained', 'on', '147', 'women', 'with', 'preterm', 'PROM']
# sentence_list:  ['All', 'women', 'were', 'expectantly', 'managed', 'without', 'tocolytics', 'until', '37', 'weeks', "'", 'gestation', 'unless', 'they', 'developed', 'clinical', 'chorioamnionitis', ',', 'or', 'nonreassuring', 'fetal', 'heart', 'rate', 'tracing', 'or', 'biophysical', 'profile']
# sentence_list:  ['The', 'rate', 'of', 'positive', 'urine', 'drug', 'screens', 'for', 'cocaine', 'was', '8.2', '%']
# sentence_list:  ['There', 'was', 'a', 'higher', 'rate', 'of', 'recent', 'cocaine', 'use', 'among', 'African-American', 'women', '(', '20.4', '%', ')', 'as', 'compared', 'to', 'non-African-Americans', '(', '1.2', '%', ',', 'p', '=', '0.0001', ')']
# sentence_list:  ['There', 'was', 'no', 'significant', 'difference', 'in', 'the', 'reason', 'for', 'delivery', 'between', 'the', 'two', 'groups', 'of', 'patients']
# sentence_list:  ['Recent', 'cocaine', 'use', 'among', 'women', 'with', 'preterm', 'PROM', 'is', 'common', 'in', 'only', 'some', 'segments', 'of', 'an', 'urban', 'population']
# sentence_list:  ['Women', 'with', 'recent', 'cocaine', 'use', 'present', 'with', 'ruptured', 'membranes', 'at', 'an', 'earlier', 'gestational', 'age', 'and', 'may', 'actually', 'have', 'a', 'longer', 'latency', 'period', 'than', 'women', 'who', 'do', 'not', 'use', 'cocaine']
# sentence_list:  ['Responses', 'to', 'an', 'interview', 'at', 'initial', 'prenatal', 'care', 'enrollment', 'were', 'compared', 'using', 'Chi-square', 'and', 'Fisher', "'s", 'exact', 'tests']
# sentence_list:  ['Of', '75', 'women', ',', 'drug', 'users', '(', '51', '%', ')', 'were', 'more', 'likely', 'to', 'say', 'that', 'they', 'would', 'defer', 'initiating', 'prenatal', 'care', '(', 'P', '=', '0.03', ')', 'and', 'to', 'minimize', 'the', 'risk', 'of', 'drug', 'or', 'alcohol', 'use', 'to', 'the', 'fetus', '(', 'P', '=', '0.04', ')']
# sentence_list:  ['Most', '(', '85', '%', ')', 'viewed', 'pregnancy', 'as', 'inappropriate', 'for', 'HIV', 'infected', 'women', 'and', 'primarily', 'drug', 'users', '(', 'P', '=', '0.06', ')', 'would', 'abort', 'if', 'HIV', 'infected']
# sentence_list:  ['Over', 'half', 'thought', 'HIV', 'transmission', 'occurred', 'most', 'times', 'or', 'always']
# sentence_list:  ['Only', '20', '%', 'had', 'heard', 'of', 'a', 'drug', 'to', 'reduce', 'this', 'risk', ',', 'but', '95', '%', 'would', 'take', 'such', 'a', 'therapy']
# sentence_list:  ['These', 'inner-city', ',', 'pregnant', 'women', 'disapproved', 'of', 'pregnancy', 'if', 'HIV', 'infected', 'and', 'thought', 'the', 'risk', 'of', 'transmission', 'was', 'high']
# sentence_list:  ['They', 'knew', 'little', 'of', 'how', 'to', 'reduce', 'this', 'risk', 'but', 'nearly', 'all', 'would', 'accept', 'a', 'drug', 'to', 'prevent', 'transmission']
# sentence_list:  ['The', 'association', 'of', 'parvovirus', 'B19', 'infection', 'and', 'hydrops', 'fetalis', 'is', 'well', 'known']
# sentence_list:  ['We', 'present', 'five', 'cases', 'of', 'isolated', 'pleural', 'or', 'pericardial', 'effusion', 'with', 'documented', 'maternal', 'parvovirus', 'infection', 'in', 'four', 'of', 'these', 'pregnancies']
# sentence_list:  ['BACKGROUND', ':', 'Cochlear', 'implantation', 'is', 'nowadays', 'a', 'reliable', 'and', 'well-accepted', 'method', 'of', 'auditory', 'rehabilitation', 'in', 'selected', 'adults', 'and', 'children']
# sentence_list:  ['METHODS', ':', 'We', 'present', 'rehabilitation', 'data', 'on', '21', 'adult', 'patients', 'provided', 'with', 'the', 'Nucleus', 'CI22', 'M', 'cochlear', 'implant', 'using', 'the', 'SPEAK', 'strategy']
# sentence_list:  ['RESULTS', ':', 'Results', 'of', 'first', 'tune-up', 'show', 'an', 'open', 'set', 'speech', 'understanding', 'in', 'approximately', '50', '%', 'of', 'patients']
# sentence_list:  ['Long-term', 'results', 'also', 'reveal', 'further', 'improvement', 'in', 'patients', 'who', 'had', 'no', 'open', 'set', 'speech', 'understanding']
# sentence_list:  ['Our', 'data', 'seem', 'to', 'indicate', 'similar', 'results', 'in', 'comparison', 'to', 'other', 'groups', 'using', 'the', 'CIS', 'strategy']
# sentence_list:  ['CONCLUSIONS', ':', 'In', 'adults', ',', 'open', 'set', 'speech', 'understanding', 'can', 'be', 'achieved', 'even', 'at', 'the', 'first', 'tune-up']
# sentence_list:  ['Adverse', 'drug', 'effects', 'are', 'manifold', 'and', 'heterogenous']
# sentence_list:  ['Many', 'situations', 'may', 'hamper', 'the', 'signalling', '(', 'i.e', '.', 'the', 'detection', 'of', 'early', 'warning', 'signs', ')', 'of', 'adverse', 'effects', 'and', 'new', 'signals', 'often', 'differ', 'from', 'previous', 'experiences']
# sentence_list:  ['Different', 'categories', 'of', 'adverse', 'effects', 'need', 'different', 'methods', 'for', 'detection']
# sentence_list:  ['Current', 'pharmacovigilance', 'is', 'predominantly', 'based', 'on', 'spontaneous', 'reporting', 'and', 'is', 'mainly', 'helpful', 'in', 'detecting', 'type', 'B', 'effects', '(', 'those', 'effects', 'that', 'are', 'often', 'allergic', 'or', 'idiosyncratic', 'reactions', ',', 'characteristically', 'occurring', 'in', 'only', 'a', 'minority', 'of', 'patients', 'and', 'usually', 'unrelated', 'to', 'dosage', 'and', 'that', 'are', 'serious', ',', 'unexpected', 'and', 'unpredictable', ')', 'and', 'unusual', 'type', 'A', 'effects', '(', 'those', 'effects', 'that', 'are', 'related', 'to', 'the', 'pharmacological', 'effects', 'of', 'the', 'drug', 'and', 'are', 'dosage-related', ')']
# sentence_list:  ['Examples', 'of', 'other', 'sources', 'of', 'signals', 'are', 'prescription', 'event', 'monitoring', ',', 'large', 'automated', 'data', 'resources', 'on', 'morbidity', 'and', 'drug', 'use', '(', 'including', 'record', 'linkage', ')', ',', 'case-control', 'surveillance', 'and', 'follow-up', 'studies']
# sentence_list:  ['A', 'proposal', 'is', 'made', 'for', 'a', 'standard', 'signal', 'management', 'procedure', 'at', 'pharmacovigilance', 'centres', ',', 'including', 'the', 'following', 'steps', ':', 'signal', 'delineation', ',', 'literature', 'search', ',', 'preliminary', 'inventory', 'of', 'data', ',', 'collection', 'of', 'additional', 'information', ',', 'consultation', 'with', 'the', 'World', 'Health', 'Organization', 'Centre', 'for', 'International', 'Drug', 'Monitoring', 'and', 'the', 'relevant', 'drug', 'companies', ',', 'aggregated', 'data', 'assessment', 'and', 'a', 'report', 'in', 'writing']
# sentence_list:  ['A', 'better', 'understanding', 'of', 'the', 'conditions', 'and', 'mechanisms', 'involved', 'in', 'the', 'detection', 'of', 'adverse', 'drug', 'effects', 'may', 'further', 'improve', 'strategies', 'for', 'pharmacovigilance']
# sentence_list:  ['OBJECTIVE', ':', 'To', 'study', 'the', 'safety', 'and', 'efficacy', 'of', 'methylphenidate', 'in', 'children', 'with', 'the', 'dual', 'diagnosis', 'of', 'epilepsy', 'and', 'attention', 'deficit', 'hyperactivity', 'disorder', '(', 'ADHD', ')']
# sentence_list:  ['STUDY', 'DESIGN', ':', 'Thirty', 'children', ',', 'aged', '6.4', 'to', '16.4', 'years', ',', 'with', 'epilepsy', 'and', 'ADHD', 'were', 'studied', 'during', 'a', '4-month', 'period']
# sentence_list:  ['During', 'the', 'initial', '2', 'months', 'of', 'the', 'study', ',', 'the', 'children', 'were', 'treated', 'with', 'antiepileptic', 'drugs', '(', 'AEDs', ')', 'only', ',', 'and', 'for', 'the', 'remaining', '2', 'months', ',', 'methylphenidate', 'was', 'added', 'at', 'a', 'morning', 'dose', 'of', '0.3', 'mg/kg']
# sentence_list:  ['They', 'underwent', 'neurologic', 'assessment', ',', 'brain', 'computed', 'tomography', ',', 'IQ', 'testing', ',', 'and', 'assessment', 'with', 'the', 'Childhood', 'Behavior', 'Checklist', 'at', 'baseline', 'before', 'methylphenidate', 'therapy']
# sentence_list:  ['Electroencephalography', ',', 'AED', 'determinations', ',', 'and', 'the', 'continuous-performance', 'task', '(', 'CPT', ')', 'test', 'were', 'done', 'at', 'baseline', 'and', 'after', '2', 'months', 'of', 'methylphenidate', 'therapy']
# sentence_list:  ['On', 'the', '2', 'days', 'of', 'testing', ',', 'the', 'child', 'received', 'AEDs', 'and', 'a', 'capsule', 'containing', 'either', 'placebo', 'or', 'methylphenidate']
# sentence_list:  ['RESULTS', ':', 'None', 'of', 'the', '25', 'children', 'of', 'this', 'sample', 'who', 'were', 'seizure', 'free', 'had', 'attacks', 'while', 'taking', 'methylphenidate']
# sentence_list:  ['Of', 'the', '5', 'children', 'with', 'seizures', ',', '3', 'had', 'an', 'increase', 'in', 'attacks', ',', 'whereas', 'the', 'other', '2', 'showed', 'no', 'change', 'or', 'a', 'reduction']
# sentence_list:  ['Methylphenidate', 'benefited', '70', '%', 'of', 'children', 'according', 'to', 'parental', 'report', ';', 'methylphenidate', 'also', 'enhanced', 'performance', 'on', 'the', 'CPT']
# sentence_list:  ['Side', 'effects', 'of', 'methylphenidate', 'were', 'mild', 'and', 'transient']
# sentence_list:  ['Caution', 'is', 'warranted', 'for', 'those', 'still', 'having', 'seizures', 'while', 'receiving', 'AED', 'therapy']
# sentence_list:  ['The', 'temporal', 'properties', 'of', 'semantic', 'and', 'phonological', 'processes', 'in', 'speech', 'production', 'were', 'investigated', 'in', 'a', 'new', 'experimental', 'paradigm', 'using', 'movement-related', 'brain', 'potentials']
# sentence_list:  ['The', 'main', 'experimental', 'task', 'was', 'picture', 'naming']
# sentence_list:  ['In', 'addition', ',', 'a', '2-choice', 'reaction', 'go/no-go', 'procedure', 'was', 'included', ',', 'involving', 'a', 'semantic', 'and', 'a', 'phonological', 'categorization', 'of', 'the', 'picture', 'name']
# sentence_list:  ['Lateralized', 'readiness', 'potentials', '(', 'LRPs', ')', 'were', 'derived', 'to', 'test', 'whether', 'semantic', 'and', 'phonological', 'information', 'activated', 'motor', 'processes', 'at', 'separate', 'moments', 'in', 'time']
# sentence_list:  ['Varying', 'the', 'position', 'of', 'the', 'critical', 'phoneme', 'in', 'the', 'picture', 'name', 'did', 'not', 'affect', 'the', 'onset', 'of', 'the', 'LRP', 'but', 'rather', 'influenced', 'when', 'the', 'LRP', 'began', 'to', 'differ', 'on', 'go', 'and', 'no-go', 'trials', 'and', 'allowed', 'the', 'duration', 'of', 'phonological', 'encoding', 'of', 'a', 'word', 'to', 'be', 'estimated']
# sentence_list:  ['The', 'sequential', 'replacement', 'of', 'the', 'four', 'tryptophan', 'residues', 'in', 'gramicidin', 'A', 'at', 'positions', '15', ',', '13', ',', '11', ',', 'and', '9', 'with', 'glycine', 'showed', 'that', 'there', 'was', 'no', 'detectable', 'effect', 'at', 'position', '15', 'but', 'increasing', 'heterogeneity', 'of', 'species', 'in', 'the', 'micelles', 'proceeding', 'toward', 'the', 'interior', 'of', 'the', 'micelle', 'at', 'position', '9']
# sentence_list:  ['The', 'replacement', 'of', 'tryptophan', 'at', 'positions', '15', 'and', '9', 'with', 'alanine', 'was', 'found', 'to', 'produce', 'more', 'species', 'heterogeneity', 'than', 'found', 'with', 'glycine', 'substitution', 'at', 'the', 'same', 'positions']
# sentence_list:  ['With', 'the', 'Gly-11', ',', 'Gly-13', ',', 'and', 'Gly-15', 'analogs', ',', 'the', 'increase', 'in', 'SDS', 'concentration', 'results', 'in', 'the', 'formation', 'of', 'a', 'single', 'species', ';', 'however', ',', 'for', 'the', 'Gly-9', ',', 'Ala-9', ',', 'and', 'Ala-15', 'analogs', ',', 'heterogeneity', 'remains']
# sentence_list:  ['Molecular', 'dynamics', 'in', 'torsion-angle', 'space', 'was', 'applied', 'to', 'nuclear', 'magnetic', 'resonance', 'structure', 'calculation', 'using', 'nuclear', 'Overhauser', 'effect-derived', 'distances', 'and', 'J-coupling-constant-derived', 'dihedral', 'angle', 'restraints']
# sentence_list:  ['Compared', 'to', 'two', 'other', 'commonly', 'used', 'algorithms', ',', 'molecular', 'dynamics', 'in', 'Cartesian', 'space', 'and', 'metric-matrix', 'geometry', 'combined', 'with', 'Cartesian', 'molecular', 'dynamics', ',', 'the', 'method', 'shows', 'increased', 'computational', 'efficiency', 'and', 'success', 'rate', 'for', 'large', 'proteins', ',', 'and', 'it', 'shows', 'a', 'dramatically', 'increased', 'radius', 'of', 'convergence', 'for', 'DNA']
# sentence_list:  ['The', 'torsion-angle', 'molecular', 'dynamics', 'algorithm', 'starts', 'from', 'an', 'extended', 'strand', 'conformation', 'and', 'proceeds', 'in', 'four', 'stages', ':', 'high-temperature', 'torsion-angle', 'molecular', 'dynamics', ',', 'slow-cooling', 'torsion-angle', 'molecular', 'dynamics', ',', 'Cartesian', 'molecular', 'dynamics', ',', 'and', 'minimization']
# sentence_list:  ['Tests', 'were', 'carried', 'out', 'using', 'experimental', 'NMR', 'data', 'for', 'protein', 'G', ',', 'interleukin-8', ',', 'villin', '14T', ',', 'and', 'a', '12', 'base-pair', 'duplex', 'of', 'DNA', ',', 'and', 'simulated', 'NMR', 'data', 'for', 'bovine', 'pancreatic', 'trypsin', 'inhibitor']
# sentence_list:  ['For', 'villin', '14T', ',', 'a', 'monomer', 'consisting', 'of', '126', 'residues', ',', 'structure', 'determination', 'by', 'torsion-angle', 'molecular', 'dynamics', 'has', 'a', 'success', 'rate', 'of', '85', '%', ',', 'a', 'more', 'than', 'twofold', 'improvement', 'over', 'other', 'methods']
# sentence_list:  ['The', 'wavelet-transform', 'method', 'is', 'used', 'to', 'quantify', 'the', 'magnetic', 'resonance', 'spectroscopy', '(', 'MRS', ')', 'parameters', ':', 'chemical', 'shift', ',', 'apparent', 'relaxation', 'time', 'T2', ',', 'resonance', 'amplitude', ',', 'and', 'phase']
# sentence_list:  ['Wavelet', 'transformation', 'is', 'a', 'time-frequency', 'representation', 'which', 'separates', 'each', 'component', 'from', 'the', 'FID', ',', 'then', 'successively', 'quantifies', 'it', 'and', 'subtracts', 'it', 'from', 'the', 'raw', 'signal']
# sentence_list:  ['Two', 'iterative', 'procedures', 'have', 'been', 'developed']
# sentence_list:  ['The', 'results', 'indicate', 'that', 'the', 'wavelet-transform', 'method', 'can', 'provide', 'efficient', 'and', 'accurate', 'quantification', 'of', 'MRS', 'data']
# sentence_list:  ['BACKGROUND', ':', 'Antiplatelet', 'therapy', 'with', 'aspirin', 'and', 'systematic', 'anticoagulation', 'with', 'warfarin', 'reduce', 'cardiovascular', 'morbidity', 'and', 'mortality', 'after', 'myocardial', 'infarction', 'when', 'given', 'alone']
# sentence_list:  ['In', 'the', 'Coumadin', 'Aspirin', 'Reinfarction', 'Study', '(', 'CARS', ')', ',', 'we', 'aimed', 'to', 'find', 'out', 'whether', 'a', 'combination', 'of', 'low-dose', 'warfarin', 'and', 'low-dose', 'aspirin', 'would', 'give', 'superior', 'results', 'to', 'standard', 'aspirin', 'monotherapy', 'without', 'excessive', 'bleeding', 'risk']
# sentence_list:  ['METHODS', ':', 'We', 'used', 'a', 'randomised', 'double-blind', 'study', 'design']
# sentence_list:  ['Patients', 'took', 'a', 'single', 'tablet', 'daily', ',', 'and', 'attended', 'for', 'prothrombin', 'time', '(', 'PT', ')', 'measurements', 'at', 'weeks', '1', ',', '2', ',', '3', ',', '4', ',', '6', ',', 'and', '12', ',', 'and', 'then', 'every', '3', 'months']
# sentence_list:  ['Patients', 'were', 'followed', 'up', 'for', 'a', 'maximum', 'of', '33', 'months', '(', 'median', '14', 'months', ')']
# sentence_list:  ['FINDINGS', ':', 'The', 'primary', 'event', 'was', 'first', 'occurrence', 'of', 'reinfarction', ',', 'non-fatal', 'ischaemic', 'stroke', ',', 'or', 'cardiovascular', 'death']
# sentence_list:  ['Primary', 'comparisons', 'were', 'done', 'with', 'all', 'follow-up', 'data']
# sentence_list:  ['The', 'relative', 'risk', 'of', 'the', 'primary', 'event', 'for', 'the', '160', 'mg', 'aspirin', 'group', 'compared', 'with', 'the', '3', 'mg', 'warfarin', 'with', '80', 'mg', 'aspirin', 'group', 'was', '0.95', '(', '0.81-1.12', ',', 'p', '=', '0.57', ')']
# sentence_list:  ['For', 'the', '3382', 'patients', 'assigned', '3', 'mg', 'warfarin', 'with', '80', 'mg', 'aspirin', ',', 'the', 'INR', 'results', 'were', ':', 'at', 'week', '1', '(', 'n', '=', '2985', ')', 'median', '1.51', '(', 'IQR', '1.23-2.13', ')', ';', 'at', 'week', '4', '(', 'n', '=', '2701', ')', '1.27', '(', '1.13-1.64', ')', ';', 'at', 'month', '6', '(', 'n', '=', '2145', ')', '1.19', '(', '1.08-1.44', ')']
# sentence_list:  ['INTERPRETATION', ':', 'Low', ',', 'fixed-dose', 'warfarin', '(', '1', 'mg', 'or', '3', 'mg', ')', 'combined', 'with', 'low-dose', 'aspirin', '(', '80', 'mg', ')', 'in', 'patients', 'who', 'have', 'had', 'myocardial', 'infarction', 'does', 'not', 'provide', 'clinical', 'benefit', 'beyond', 'that', 'achievable', 'with', '160', 'mg', 'aspirin', 'monotherapy']
# sentence_list:  ['BACKGROUND', ':', 'There', 'is', 'serological', 'evidence', 'for', 'an', 'association', 'between', 'Chlamydia', 'pneumoniae', 'and', 'coronary', 'heart', 'disease']
# sentence_list:  ['We', 'investigated', 'the', 'hypothesis', 'that', 'an', 'antichlamydial', 'macrolide', 'antibiotic', ',', 'roxithromycin', ',', 'can', 'prevent', 'or', 'reduce', 'recurrent', 'major', 'ischaemic', 'events', 'in', 'patients', 'with', 'unstable', 'angina']
# sentence_list:  ['Patients', 'were', 'randomly', 'assigned', 'either', 'roxithromycin', '150', 'mg', 'orally', 'twice', 'a', 'day', '(', 'n', '=', '102', ')', 'or', 'placebo', 'orally', 'twice', 'a', 'day', '(', 'n', '=', '100', ')']
# sentence_list:  ['Patients', 'were', 'followed', 'up', 'for', '6', 'months']
# sentence_list:  ['We', 'report', 'the', 'primary', 'clinical', 'endpoints', '(', 'cardiac', 'ischaemic', 'death', ',', 'myocardial', 'infarction', ',', 'and', 'severe', 'recurrent', 'ischaemia', ')', ',', 'assessed', 'at', 'day', '31', ',', 'in', '202', 'patients', 'on', 'an', 'intention-to-treat', 'basis']
# sentence_list:  ['FINDINGS', ':', 'A', 'statistically', 'significant', 'reduction', 'in', 'the', 'primary', 'composite', 'triple', 'endpoint', 'rates', 'was', 'observed', 'in', 'the', 'roxithromycin', 'group', ':', 'p', '=', '0.032']
# sentence_list:  ['The', 'rate', 'of', 'severe', 'recurrent', 'ischaemia', ',', 'myocardial', 'infarction', ',', 'and', 'ischaemic', 'death', 'was', '5.4', '%', ',', '2.2', '%', ',', 'and', '2.2', '%', 'in', 'the', 'placebo', 'group', 'and', '1.1', '%', ',', '0', '%', ',', 'and', '0', '%', ',', 'in', 'the', 'roxithromycin', 'group', ',', 'respectively']
# sentence_list:  ['No', 'major', 'drug-related', 'adverse', 'effects', 'were', 'observed']
# sentence_list:  ['Large-scale', 'trials', 'are', 'needed', 'to', 'confirm', 'these', 'preliminary', 'observations']
# sentence_list:  ['BACKGROUND', ':', 'Stage', 'Ib', 'and', 'IIa', 'cervical', 'carcinoma', 'can', 'be', 'cured', 'by', 'radical', 'surgery', 'or', 'radiotherapy']
# sentence_list:  ['These', 'two', 'procedures', 'are', 'equally', 'effective', ',', 'but', 'differ', 'in', 'associated', 'morbidity', 'and', 'type', 'of', 'complications']
# sentence_list:  ['In', 'this', 'prospective', 'randomised', 'trial', 'of', 'radiotherapy', 'versus', 'surgery', ',', 'our', 'aim', 'was', 'to', 'assess', 'the', '5-year', 'survival', 'and', 'the', 'rate', 'and', 'pattern', 'of', 'complications', 'and', 'recurrences', 'associated', 'with', 'each', 'treatment']
# sentence_list:  ['METHODS', ':', 'Between', 'September', ',', '1986', ',', 'and', 'December', ',', '1991', ',', '469', 'women', 'with', 'newly', 'diagnosed', 'stage', 'Ib', 'and', 'IIa', 'cervical', 'carcinoma', 'were', 'referred', 'to', 'our', 'institute']
# sentence_list:  ['Adjuvant', 'radiotherapy', 'was', 'delivered', 'after', 'surgery', 'for', 'women', 'with', 'surgical', 'stage', 'pT2b', 'or', 'greater', ',', 'less', 'than', '3', 'mm', 'of', 'safe', 'cervical', 'stroma', ',', 'cut-through', ',', 'or', 'positive', 'nodes']
# sentence_list:  ['The', 'primary', 'outcome', 'measures', 'were', '5-year', 'survival', 'and', 'the', 'rate', 'of', 'complications']
# sentence_list:  ['The', 'analysis', 'of', 'survival', 'and', 'recurrence', 'was', 'by', 'intention', 'to', 'treat', 'and', 'analysis', 'of', 'complications', 'was', 'by', 'treatment', 'delivered']
# sentence_list:  ['FINDINGS', ':', '170', 'patients', 'in', 'the', 'surgery', 'group', 'and', '167', 'in', 'the', 'radiotherapy', 'group', 'were', 'included', 'in', 'the', 'intention-to-treat', 'analysis', ';', 'scheduled', 'treatment', 'was', 'delivered', 'to', '169', 'and', '158', 'women', ',', 'respectively', ',', '62', 'of', '114', 'women', 'with', 'cervical', 'diameters', 'of', '4', 'cm', 'or', 'smaller', 'and', '46', 'of', '55', 'with', 'diameters', 'larger', 'than', '4', 'cm', 'received', 'adjuvant', 'therapy']
# sentence_list:  ['After', 'a', 'median', 'follow-up', 'of', '87', '(', 'range', '57-120', ')', 'months', ',', '5-year', 'overall', 'and', 'disease-free', 'survival', 'were', 'identical', 'in', 'the', 'surgery', 'and', 'radiotherapy', 'groups', '(', '83', '%', 'and', '74', '%', ',', 'respectively', ',', 'for', 'both', 'groups', ')', ',', '86', 'women', 'developed', 'recurrent', 'disease', ':', '42', '(', '25', '%', ')', 'in', 'the', 'surgery', 'group', 'and', '44', '(', '26', '%', ')', 'in', 'the', 'radiotherapy', 'group']
# sentence_list:  ['Significant', 'factors', 'for', 'survival', 'in', 'univariate', 'and', 'multivariate', 'analyses', 'were', ':', 'cervical', 'diameter', ',', 'positive', 'lymphangiography', ',', 'and', 'adeno-carcinomatous', 'histotype']
# sentence_list:  ['48', '(', '28', '%', ')', 'surgery-group', 'patients', 'had', 'severe', 'morbidity', 'compared', 'with', '19', '(', '12', '%', ')', 'radiotherapy-group', 'patients', '(', 'p', '=', '0.0004', ')']
# sentence_list:  ['The', 'combination', 'of', 'surgery', 'and', 'radiotherapy', 'has', 'the', 'worst', 'morbidity', ',', 'especially', 'urological', 'complications']
# sentence_list:  ['The', 'optimum', 'therapy', 'for', 'each', 'patient', 'should', 'take', 'account', 'of', 'clinical', 'factors', 'such', 'as', 'menopausal', 'status', ',', 'age', ',', 'medical', 'illness', ',', 'histological', 'type', ',', 'and', 'cervical', 'diameter', 'to', 'yield', 'the', 'best', 'cure', 'with', 'minimum', 'complications']
# sentence_list:  ['Today', "'s", 'technology', 'links', 'health', 'care', 'providers', 'and', 'patients', 'across', 'town', ',', 'in', 'the', 'next', 'state', 'or', 'even', 'another', 'country']
# sentence_list:  ['Nursing', 'across', 'state', 'lines', 'poses', 'complications', ':', 'state-bound', 'regulatory', 'and', 'licensure', 'issues']
# sentence_list:  ['Early', 'introduction', 'of', 'enteral', 'feeds', 'and', 'the', 'use', 'of', 'nutritional', 'modulation', 'are', 'emphasized']
# sentence_list:  ['PROBLEM', ':', 'To', 'compare', 'the', 'expression', 'by', 'T-lymphocytes', 'of', 'an', 'immunomodulatory', 'protein', 'known', 'as', 'progesterone-induced', 'blocking', 'factor', '(', 'PIBF', ')', 'in', 'conception', 'versus', 'non-conception', 'cycles', 'even', 'when', 'there', 'has', 'been', 'definite', 'fertilization', 'and', 'embryo', 'formation']
# sentence_list:  ['METHOD', ':', 'PIBF', 'expression', 'on', 'T', 'lymphocytes', 'was', 'measured', 'using', 'an', 'immunohistochemical', 'method', 'with', 'a', 'PIBF-specific', 'polyclonal', 'antibody']
# sentence_list:  ['There', 'were', 'no', 'differences', 'in', 'PIBF', 'levels', 'by', 'therapy', 'used', 'in', 'non-pregnant', 'cases', 'or', 'in', 'the', 'pregnant', 'group']
# sentence_list:  ['CONCLUSION', ':', 'These', 'data', 'are', 'consistent', 'with', 'the', 'hypothesis', 'that', 'maternal', 'expression', 'of', 'PIBF', 'in', 'T-lymphocytes', 'soon', 'after', 'trophoblast', 'invasion', 'may', 'depend', 'on', 'successful', 'implantation']
# ...
# sentence_list:  ['Besides', 'the', 'well-known', 'nonsteroidal', 'antiinflammatory', 'drugs', '(', 'NSAID', ')', 'for', 'the', 'treatment', 'of', 'rheumatic', 'pain', 'herbal', 'medicine', 'can', 'also', 'be', 'applied', 'successfully']
# sentence_list:  ['High-dose', 'intravenous', 'immunoglobulin', '(', 'hdIVIg', ')', 'is', 'increasingly', 'used', 'to', 'treat', 'a', 'range', 'of', 'inflammatory', 'and', 'autoimmune', 'diseases']
# sentence_list:  ['We', 'describe', 'a', 'technique', 'that', 'enables', 'the', 'autologous', 'repair', 'of', 'large', 'midline', 'incisional', 'hernias', 'by', 'restoring', 'the', 'functional', 'musculoaponeurotic', 'support', 'of', 'the', 'abdominal', 'wall']
# sentence_list:  ['METHODS', ':', 'During', 'a', '19-month', 'period', ',', 'seven', 'children', 'with', 'empyema', 'underwent', 'thoracoscopy']
# sentence_list:  ['While', 'these', 'findings', 'are', 'observed', 'for', 'all', 'classes', 'of', 'oral', 'drugs', ',', 'the', 'issue', 'is', 'especially', 'critical', 'for', 'cancer', 'chemotherapy', ',', 'in', 'which', 'a', 'narrow', 'therapeutic', 'index', 'is', 'frequently', 'observed']
# sentence_list:  ['Therefore', ',', 'interest', 'is', 'growing', 'in', 'mAbs', 'as', 'therapeutic', 'alternatives', 'for', 'patients', 'with', 'low-grade', 'NHL', 'and', 'those', 'with', 'transformed', 'histology']
# sentence_list:  ['The', 'activity', 'of', 'oral', 'UFT', 'in', 'large-bowel', 'cancer', 'when', 'administered', 'with', 'oral', 'LV', '(', 'approximately', '50', 'mg/dose', ')', 'has', 'resulted', 'in', 'objective', 'response', 'rates', 'of', 'approximately', '40', '%']
# sentence_list:  ['CONCLUSION', ':', 'UFT', 'is', 'a', 'fluoropyrimidine', 'active', 'in', 'colorectal', 'cancer']
# sentence_list:  ['BACKGROUND', ':', 'Adrenalectomy', 'is', 'the', 'current', 'treatment', 'for', 'phaeochromocytoma']
# sentence_list:  ['As', 'single', 'agent', 'therapy', 'in', 'malignant', 'melanoma', ',', 'interferon', 'alfa-2a', 'was', 'only', 'marginally', 'useful', 'in', 'most', 'patients']
# sentence_list:  ['Studies', 'with', 'various', 'interferon', 'alpha', 'preparations', ',', 'including', 'interferons', 'induced', 'in', 'human', 'leukocytes', ',', 'interferon', 'alfa-N1', ',', 'interferon', 'alfa-2a', ',', 'and', 'interferon', 'alfa-2b', ',', 'have', 'all', 'provided', 'evidence', 'for', 'modest', 'but', 'reproducible', 'antitumor', 'activity', 'in', 'advanced', 'renal', 'cell', 'carcinoma']
# sentence_list:  ['The', 'rationale', 'for', 'antileukemic', 'therapy', 'in', 'hairy', 'cell', 'leukemia', 'is', 'to', 'reduce', 'the', 'significant', 'risk', 'of', 'infection', 'and', 'other', 'potential', 'serious', 'complications']
# sentence_list:  ['Recombinant', 'and', 'natural', 'forms', 'of', 'interferon', 'alpha', 'have', 'been', 'shown', 'to', 'bring', 'about', 'tumor', 'regressions', 'in', 'patients', 'with', 'low-grade', 'non-Hodgkin', "'s", 'lymphoma']
# sentence_list:  ['Current', 'studies', 'using', 'interferon', 'in', 'patients', 'with', 'low-grade', 'non-Hodgkin', "'s", 'lymphomas', 'are', 'evaluating', 'lower', ',', 'and', 'perhaps', 'better', 'tolerated', 'doses', 'of', 'interferon']
# sentence_list:  ['While', 'the', 'demonstrated', 'antiviral', ',', 'antiproliferative', ',', 'and', 'immunomodulatory', 'properties', 'of', 'interferons', 'have', 'led', 'to', 'a', 'number', 'of', 'theories', 'regarding', 'their', 'potential', 'use', 'in', 'treating', 'individuals', 'with', 'chronic', 'myelogenous', 'leukemia', '(', 'CML', ')', ',', 'their', 'limited', 'availability', 'has', 'prevented', 'thorough', 'clinical', 'investigation']
# sentence_list:  ['Intrathecal', 'sufentanil', 'provides', 'approximately', '2', 'h', 'of', 'excellent', 'labor', 'analgesia', 'with', 'minimal', 'motor', 'blockade']
# sentence_list:  ['OBJECTIVE', ':', 'We', 'report', 'the', 'results', 'of', 'a', 'double-blind', ',', 'double-dummy', ',', 'active-control', 'study', 'designed', 'to', 'evaluate', 'the', 'efficacy', 'and', 'safety', 'of', 'lamotrigine', '(', 'LTG', ')', 'administered', 'as', 'monotherapy', 'to', 'adult', 'outpatients', 'with', 'partial', 'seizures']
# sentence_list:  ['We', 'conducted', 'a', 'long-term', 'trial', 'of', 'docosahexanoic', 'acid', '(', 'DHA', ')', '-concentrated', 'fish', 'oil', 'capsules', 'for', 'patients', 'in', 'a', 'high-risk', 'group', 'for', 'colorectal', 'cancer']
# sentence_list:  ['This', 'article', 'reviews', 'current', 'trends', 'in', 'management', 'of', 'esophageal', 'achalasia', ',', 'highlighting', 'short-term', 'outcome', 'and', 'cost', 'comparisons', 'of', 'three', 'treatments', ':', 'botulinum', 'toxin', 'injection', ',', 'pneumatic', 'dilation', ',', 'and', 'laparoscopic', 'myotomy']
# sentence_list:  ['The', 'clinical', 'application', 'of', 'therapeutic', 'hysteroscopy', ',', 'mainly', 'in', 'the', 'field', 'of', 'the', 'treatment', 'of', 'abnormal', 'uterine', 'bleeding', ',', 'started', 'in', 'the', '1980s']
# sentence_list:  ['Treatment', 'of', 'irritable', 'bowel', 'syndrome', 'with', 'Chinese', 'herbal', 'medicine', ':', 'a', 'randomized', 'controlled', 'trial']
# sentence_list:  ['Tubularized', 'incised', 'plate', 'hypospadias', 'repair', 'for', 'proximal', 'hypospadias']
# sentence_list:  ['Comparison', 'of', 'radical', 'prostatectomy', 'and', 'iodine', '125', 'interstitial', 'radiotherapy', 'for', 'the', 'treatment', 'of', 'clinically', 'localized', 'prostate', 'cancer', ':', 'a', '7-year', 'biochemical', '(', 'PSA', ')', 'progression', 'analysis']
# sentence_list:  ['Immunotherapy', 'of', 'tumors', 'with', 'autologous', 'tumor-derived', 'heat', 'shock', 'protein', 'preparations']
# sentence_list:  ['European', 'register', 'of', 'patients', 'with', 'sickle', 'cell', 'disease', 'treated', 'with', 'hydroxyurea', 'is', 'being', 'set', 'up']
# sentence_list:  ['Haematoma', 'block', 'versus', 'intravenous', 'regional', 'anaesthesia', 'in', 'Colles', "'", 'fractures']
# sentence_list:  ['Protective', 'effect', 'of', 'pralidoxime', 'on', 'muscle', 'fiber', 'necrosis', 'induced', 'by', 'organophosphate', 'compounds']
# sentence_list:  ['Statins', 'for', 'prevention', 'of', 'stroke']
# sentence_list:  ['Effect', 'of', 'photodynamic', 'therapy', 'in', 'combination', 'with', 'mitomycin', 'C', 'on', 'a', 'mitomycin-resistant', 'bladder', 'cancer', 'cell', 'line']
# sentence_list:  ['In', 'vitro', 'and', 'in', 'vivo', 'comparison', 'between', 'the', 'effects', 'of', 'treatment', 'with', 'adenosine', 'triphosphate', 'and', 'treatment', 'with', 'buthionine', 'sulfoximine', 'on', 'chemosensitization', 'and', 'tumour', 'growth', 'of', 'B16', 'melanoma']
# sentence_list:  ['Effects', 'of', 'transpupillary', 'thermotherapy', 'on', 'immunological', 'parameters', 'and', 'apoptosis', 'in', 'a', 'case', 'of', 'primary', 'uveal', 'melanoma']
# sentence_list:  ['Nerve-sparing', 'surgery', 'for', 'advanced', 'rectal', 'cancer', 'patients', ':', 'special', 'reference', 'to', 'Dukes', 'C', 'patients']
# sentence_list:  ['Current', 'surgical', 'therapy', 'for', 'bronchiectasis']
# sentence_list:  ['Thoracoscopic', 'surgery', 'for', 'spontaneous', 'pneumothorax']
# sentence_list:  ['Transabdominal', 'extensive', 'esophagogastric', 'devascularization', 'with', 'gastroesophageal', 'stapling', 'for', 'management', 'of', 'noncirrhotic', 'portal', 'hypertension', ':', 'long-term', 'results']
# sentence_list:  ['Sliding', 'door', 'technique', 'for', 'the', 'repair', 'of', 'midline', 'incisional', 'hernias']
# sentence_list:  ['Thoracoscopy', 'for', 'empyema', 'in', 'children']
# sentence_list:  ['Conventional', 'treatments', 'for', 'non-Hodgkin', "'s", 'lymphoma', ':', 'the', 'need', 'for', 'new', 'therapies']
# sentence_list:  ['Antiplatelet', 'therapy', 'in', 'acute', 'cerebral', 'ischemia']
# sentence_list:  ['Excimer', 'laser', 'assisted', 'in', 'situ', 'keratomileusis', 'for', 'hyperopia']
# sentence_list:  ['Interferon', 'treatment', 'of', 'renal', 'cell', 'carcinoma']
# sentence_list:  ['Antimicrobial', 'treatment', 'options', 'in', 'the', 'management', 'of', 'odontogenic', 'infections']
# sentence_list:  ['An', 'active-control', 'trial', 'of', 'lamotrigine', 'monotherapy', 'for', 'partial', 'seizures']
# sentence_list:  ['Gene', 'therapy', 'for', 'myocardial', 'angiogenesis']
# sentence_list:  ['Acid', 'suppression', 'therapy', 'in', 'Barrett', "'s", 'esophagus', ':', 'the', 'importance', 'of', 'pH', 'monitoring']
# sentence_list:  ['Physiologic', 'treatment', 'of', 'depressive', 'reactions', ':', 'a', 'pilot', 'study']
# sentence_list:  ['Treatment', 'of', 'hydrocele', 'and', 'cysts', 'of', 'the', 'epididymis', 'with', 'sclerosing', 'injections', 'of', 'quinine', 'and', 'urea', 'chlorhydrolactate', 'in', 'a', '30', 'per', 'cent', 'solution']
# sentence_list:  ['The', 'treatment', 'of', 'autoimmune', 'hemolytic', 'anemia', 'with', 'heparin']
# sentence_list:  ['Effects', 'of', 'clomiphene', 'citrate', 'on', 'endometrial', 'hyperplasia', 'in', 'the', 'premenopausal', 'female']
# sentence_list:  ['Prolonged', 'use', 'of', 'methyldopa', 'in', 'severe', 'hypertension', 'in', 'pregnancy']
# sentence_list:  ['Glutathione', 'S-transferase', 'activity', 'in', 'epithelial', 'ovarian', 'cancer', ':', 'association', 'with', 'response', 'to', 'chemotherapy', 'and', 'disease', 'outcome']
# sentence_list:  ['<', 'TO_SEE', '>', 'Frontal', 'dysfunction', 'blocks', 'the', 'therapeutic', 'effect', 'of', 'THA', 'on', 'attention', 'in', 'Alzheimer', "'s", 'disease']
# sentence_list:  ['Corticosteroid', 'injections', 'for', 'sciatica']
# sentence_list:  ['<', 'TO_SEE', '>', 'Antiplatelet', 'therapy', 'to', 'prevent', 'stroke', ':', 'risk', 'of', 'brain', 'hemorrhage', 'and', 'efficacy', 'in', 'atrial', 'fibrillation']
# sentence_list:  ['Another', 'potential', 'use', 'of', 'troglitazone', 'in', 'noninsulin-dependent', 'diabetes', 'mellitus']
# sentence_list:  ['Are', 'ABVD', 'and', 'MOPP/ABV', 'truly', 'equivalent', 'for', 'treating', 'Hodgkin', "'s", 'disease', 'at', 'advanced', 'stages', '?']
# sentence_list:  ['Paclitaxel', 'for', 'the', 'treatment', 'of', 'lymphoma']
# sentence_list:  ['Percutaneous', 'transluminal', 'angioplasty', 'in', 'the', 'treatment', 'of', 'renovascular', 'hypertension', ':', 'sequential', 'prospective', 'study']
# sentence_list:  ['A', 'comparison', 'of', 'rectal', 'diazepam', 'gel', 'and', 'placebo', 'for', 'acute', 'repetitive', 'seizures']
# sentence_list:  ['5-year', 'outcome', 'of', 'surgical', 'resection', 'and', 'watchful', 'waiting', 'for', 'men', 'with', 'moderately', 'symptomatic', 'benign', 'prostatic', 'hyperplasia', ':', 'a', 'Department', 'of', 'Veterans', 'Affairs', 'cooperative', 'study']
# sentence_list:  ['Single', 'or', 'double', 'lung', 'transplantation', 'for', 'pulmonary', 'hypertension']
# sentence_list:  ['Interferon', 'beta', 'treatment', 'for', 'multiple', 'sclerosis']
# sentence_list:  ['Intravenous', 'immunoglobulin', 'treatment', 'in', 'multiple', 'sclerosis']
# sentence_list:  ['Perceived', 'contraindications', 'to', 'thrombolytic', 'treatment', 'in', 'acute', 'myocardial', 'infarction']
# sentence_list:  ['Antibiotics', 'after', 'dog', 'bite']
# sentence_list:  ['Stereotactic', 'radiosurgery', 'for', 'acoustic', 'neuroma', ':', 'a', 'Canadian', 'perspective']
# sentence_list:  ['Hematopoietic', 'stem-cell', 'transplantation', 'for', 'the', 'treatment', 'of', 'severe', 'combined', 'immunodeficiency']
# sentence_list:  ['Hyperbaric', 'oxygen', 'therapy', 'for', 'children', 'with', 'cerebral', 'palsy']
# sentence_list:  ['Peripheral', 'retinal', 'cryotherapy', 'for', 'postvitrectomy', 'diabetic', 'vitreous', 'hemorrhage', 'in', 'phakic', 'patients']
# sentence_list:  ['Hyperbaric', 'or', 'normobaric', 'oxygen', 'for', 'acute', 'carbon', 'monoxide', 'poisoning', ':', 'a', 'randomised', 'controlled', 'clinical', 'trial']
# sentence_list:  ['Matrix', 'metalloproteinase', 'inhibitors', 'in', 'the', 'treatment', 'of', 'cancer']
# sentence_list:  ['A', 'randomized', ',', 'controlled', 'study', 'in', 'adults', 'of', 'the', 'immunogenicity', 'of', 'a', 'novel', 'hepatitis', 'B', 'vaccine', 'containing', 'MF59', 'adjuvant']
# sentence_list:  ['Protection', 'of', 'swine', 'from', 'foot-and-mouth', 'disease', 'with', 'one', 'dose', 'of', 'an', 'all-D', 'retro', 'peptide']
# sentence_list:  ['Field', 'evaluation', 'of', 'the', 'clinical', 'effectiveness', 'of', 'vaccines', 'against', 'pertussis', ',', 'measles', ',', 'rubella', 'and', 'mumps', ':', 'comments']
# sentence_list:  ['Transmural', 'drainage', 'of', 'pancreatic', 'fluid', 'collections', 'without', 'electrocautery', 'using', 'the', 'Seldinger', 'technique']
# sentence_list:  ['Alterations', 'of', 'monocyte', 'function', 'in', 'patients', 'with', 'growth', 'hormone', '(', 'GH', ')', 'deficiency', ':', 'effect', 'of', 'substitutive', 'GH', 'therapy']
# sentence_list:  ['<', 'TO_SEE', '>', 'Safety', 'trial', 'with', 'the', '5HT1B/1D', 'agonist', 'avitriptan', '(', 'BMS-180048', ')', 'in', 'patients', 'with', 'migraine', 'who', 'have', 'experienced', 'pressure', ',', 'tightness', ',', 'and/or', 'pain', 'in', 'the', 'chest', ',', 'neck', ',', 'and/or', 'throat', 'following', 'sumatriptan']
# sentence_list:  ['The', 'outcome', 'of', 'arthroscopic', 'treatment', 'of', 'temporomandibular', 'joint', 'arthropathy']
# sentence_list:  ['Neostigmine', 'for', 'acute', 'colonic', 'pseudo-obstruction']
# sentence_list:  ['<', 'TO_SEE', '>', 'The', 'effect', 'of', 'bisoprolol', 'on', 'perioperative', 'mortality', 'and', 'myocardial', 'infarction', 'in', 'high-risk', 'patients', 'undergoing', 'vascular', 'surgery']
# sentence_list:  ['Surgical', 'management', 'of', 'severe', 'secondary', 'peritonitis']
# sentence_list:  ['Treatment', 'of', 'hypertension', 'with', 'ascorbic', 'acid']
# sentence_list:  ['Efficacy', 'of', 'open-bite', 'treatment', 'with', 'the', 'Thera-spoon']
# sentence_list:  ['Hepatic', 'arterial', 'infusion', 'of', 'chemotherapy', 'after', 'resection', 'of', 'hepatic', 'metastases', 'from', 'colorectal', 'cancer']
# sentence_list:  ['Evidence', 'for', 'double', 'resistance', 'to', 'permethrin', 'and', 'malathion', 'in', 'head', 'lice']
# sentence_list:  ['Urgent', 'colonoscopy', 'for', 'the', 'diagnosis', 'and', 'treatment', 'of', 'severe', 'diverticular', 'hemorrhage']
# sentence_list:  ['Effects', 'of', 'tolcapone', ',', 'a', 'catechol-O-methyltransferase', 'inhibitor', ',', 'on', 'motor', 'symptoms', 'and', 'pharmacokinetics', 'of', 'levodopa', 'in', 'patients', 'with', 'Parkinson', "'s", 'disease', '.']
# sentence_list:  ['Dry', 'powdered', 'formoterol', ',', 'twice', 'a', 'day', 'versus', 'aerosolized', 'salbutamol', ',', 'four', 'times', 'a', 'day', ',', 'in', 'patients', 'with', 'stable', 'asthma']
# sentence_list:  ['Celecoxib', 'for', 'arthritis']
# sentence_list:  ['Poliomyelitis', 'prevention', ':', 'revised', 'recommendations', 'for', 'use', 'of', 'inactivated', 'and', 'live', 'oral', 'poliovirus', 'vaccines']
# sentence_list:  ['Brimonidine', 'tartrate', '0.2', '%', 'twice', 'daily', 'vs', 'timolol', '0.5', '%', 'twice', 'daily', ':', '1-year', 'results', 'in', 'glaucoma', 'patients']
# sentence_list:  ['Epoetin', ':', 'a', 'pharmacoeconomic', 'review', 'of', 'its', 'use', 'in', 'chronic', 'renal', 'failure', 'and', 'its', 'effects', 'on', 'quality', 'of', 'life']
# sentence_list:  ['Reduction', 'of', 'vasoreactivity', 'and', 'thrombogenicity', 'with', 'laser-thermal', 'angioplasty', ':', 'comparison', 'with', 'balloon', 'angioplasty']
# sentence_list:  ['Effects', 'of', 'ultrasound', 'energy', 'on', 'total', 'peripheral', 'artery', 'occlusions', ':', 'initial', 'angiographic', 'and', 'angioscopic', 'results', '.']
# sentence_list:  ['High-dose', 'chemotherapy', 'with', 'autologous', 'stem-cell', 'support', 'for', 'epithelial', 'ovarian', 'cancer']
# sentence_list:  ['``', 'Tandem', "''", 'high-dose', 'chemoradiotherapy', 'with', 'autologous', 'stem-cell', 'support', 'in', 'the', 'treatment', 'of', 'newly', 'diagnosed', 'or', 'responsive', 'multiple', 'myeloma']
# sentence_list:  ['Intravenous', 'immune', 'globulin', 'for', 'recurrent', 'spontaneous', 'abortion']

# %% [markdown]
# ### Define the labels as the target variable for test and the train dataset

# %%
y_train = [getLabelsInListForOneSentence(labels) for labels in train_label]
y_test = [getLabelsInListForOneSentence(labels) for labels in test_label]

# %% [markdown]
# ### Build the CRF Model

# %%
# Build the CRF model.
crf = sklearn_crfsuite.CRF(max_iterations=100)

try:
    crf.fit(X_train, y_train)
except AttributeError:
    pass

# %% [markdown]
# ### Evaluation

# %% [markdown]
# ### Predict the labels of each of the tokens in each sentence of the test dataset that has been pre processed earlier.

# %%
# predicting values
y_pred = crf.predict(X_test)

# %% [markdown]
# ### Calculate the f1 score using the actual labels and the predicted labels of the test dataset

# %%
# calculating F1 score
metrics.flat_f1_score(y_test, y_pred, average='weighted')
# Out:
# 0.9042560946986944

# %% [markdown]
# ### Create the logic to get all the predicted treatments (T) labels corresponding to each disease (D) label in the test dataset

# %%
medication_data =  {} # Initialize a dictionary where we need to store disease treatment data


for i in range(len(y_pred)): # getting the predicted sequence labels
    labels = y_pred[i]
    disease = "";
    treatment = "";
  
    for j in range(len(labels)): # j is the words in a sentence
        if labels[j] == 'O': # if the label is 'o' no action required and getting the next label
            continue

        if(labels[j] == 'D'):  # if the label is 'D' store the correspoding word in disease variable and taking next label
            disease += test_sentence[i].split()[j] + " "
            continue

        if(labels[j] == 'T'): # if label is 'T' store the corresponding word in treatment
            treatment += test_sentence[i].split()[j] + " "
            
   # removing unnecessary space using strip()
    disease = disease.strip()
    treatment = treatment.strip()


    if disease is not "" and treatment is not "": # if we getting both disease and treatment from one sentence store the data
        if disease not in medication_data.keys():
            medication_data[disease] = [treatment]
        else:
            treatment_list = medication_data.get(disease)
            treatment_list.append(treatment)
            medication_data[disease] = treatment_list
# Out:
# <>:25: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# <>:25: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# <>:25: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# <>:25: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# C:\Users\Sush_Sneh\AppData\Local\Temp\ipykernel_3664\1132695696.py:25: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   if disease is not "" and treatment is not "": # if we getting both disease and treatment from one sentence store the data
# C:\Users\Sush_Sneh\AppData\Local\Temp\ipykernel_3664\1132695696.py:25: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   if disease is not "" and treatment is not "": # if we getting both disease and treatment from one sentence store the data

# %%
# checking the dictionary where we store the disease and respective treatment
medication_data
# Out:
# {'hereditary retinoblastoma': ['radiotherapy'],
#  'unstable angina or non-Q-wave myocardial infarction': ['roxithromycin'],
#  'coronary-artery disease': ['Antichlamydial antibiotics'],
#  'cellulitis': ['G-CSF therapy intravenous antibiotic treatment'],
#  'foot infection': ['G-CSF treatment'],
#  "early Parkinson 's disease": ['Ropinirole monotherapy'],
#  'female stress urinary incontinence': ['surgical treatment'],
#  'stress urinary incontinence': ['therapy'],
#  'preeclampsia ( proteinuric hypertension )': ['intrauterine insemination with donor sperm versus intrauterine insemination'],
#  'cancer': ['organ transplantation and chemotherapy',
#   'oral drugs chemotherapy'],
#  'major pulmonary embolism': ['Thrombolytic treatment right-side hemodynamics'],
#  'malignant pleural mesothelioma': ['thoracotomy , radiotherapy , and chemotherapy'],
#  'pulmonary symptoms attributable': ['chemotherapy'],
#  'non-obstructive azoospermia': ['testicular fine needle aspiration ( TEFNA ) open biopsy and testicular sperm extraction ( TESE )'],
#  'colorectal cancer': ['Elective surgery'],
#  'bronchial asthma': ['Non-steroidal anti-inflammatory therapy'],
#  "Parkinson 's disease": ['Microelectrode-guided posteroventral pallidotomy'],
#  'soft tissue sarcomas': ['Radiotherapy'],
#  "Eisenmenger 's syndrome": ['laparoscopic cholecystectomy'],
#  'advanced esophageal cancer': ['adjuvant chemoradiotherapy with CDDP'],
#  'breast cancer': ['Hormone replacement therapy',
#   'undergone subcutaneous mastectomy and immediate reconstruction'],
#  'leukemia': ['Trisomy'],
#  'some malignant tumors such as non-small cell lung cancer': ['surgery'],
#  'inoperable advanced malignancies such as colorectal cancer': ['combination with leucovorin or cisplatin'],
#  'inflammatory skin diseases': ['topical corticosteroids'],
#  'unresectable stage iii nsclc': ['studies involving sequential chemotherapy'],
#  'nsclc nsclc ( stage iiib ) sclc': ['got surgical treatment radiotherapy'],
#  'nsclc': ['platinum-based chemotherapy',
#   'evaluate planned sequential chemotherapy'],
#  'locally advanced non-small-cell lung cancer ( la-nsclc )': ['chemotherapy and radiotherapy )'],
#  'radiation-induced myelopathy': ['heparin and enoxaparin'],
#  'limited stage small cell lung cancer': ['vip combination chemotherapy'],
#  'malignant pleural effusions from nsclc': ['systemic chemotherapy'],
#  'small-cell lung cancer': ['chemotherapy', 'combination chemotherapy'],
#  'intraluminal early-stage cancer': ['photodynamic therapy'],
#  'pathologic stage i non-small cell lung cancer': ['postoperative oral administration'],
#  'supraclavicular node metastases in nsclc': ['chemoradiotherapy'],
#  'non-small-cell-lung-cancer ( nsclc )': ['cisplatin and radiotherapy'],
#  'lung carcinoma': ['videothoracoscopic lobectomy or partial resection an open thoracotomy'],
#  'stage 0 lung carcinoma': ['curative therapy'],
#  'ovarian carcinoma brain metastasis': ['surgical resection'],
#  'colorectal metastases': ['therapeutic vats metastasectomy'],
#  'limited-stage small-cell carcinoma': ['combined-modality therapy'],
#  'advanced nsclc assessing': ['combination chemotherapy of cisplatin , ifosfamide and irinotecan with rhg-csf support'],
#  'metastatic colorectal cancer': ['intravenous oxaliplatin'],
#  "non-hodgkin 's lymphoma , breast cancer mesothelioma and non-small cell lung cancer": ['oxaliplatin'],
#  'platinum-pretreated ovarian cancer': ['oxaliplatin'],
#  'non-small cell lung cancer advanced hormone refractory prostate cancer': ['combination with paclitaxel and carboplatin'],
#  'primary lung cancer adenocarcinoma squamous cell carcinoma': ['resection'],
#  'stage iii nsclc': ['chemotherapy administered before surgery'],
#  'small cell lung cancer': ['prophylactic cranial irradiation prolongs'],
#  'primary cancer': ['adjuvant radiation therapy', 'Immunotherapy'],
#  'advanced non -- small-cell lung cancer': ['determine whether paclitaxel plus carboplatin ( pc ) vinorelbine plus cisplatin ( vc )'],
#  'two-year survivors among sclc limited disease extensive disease': ['platinum dose ( cisplatin plus carboplatin ) in combination chemotherapy combination therapy with carboplatin alone'],
#  'untreated small cell lung cancer ( sclc ) untreated sclc': ['chemotherapy'],
#  'neutropenia during cancer': ['chemotherapy'],
#  'head and neck cancer =2 xerostomia': ['irradiation therapy intravenous amifostine'],
#  'disseminated malignant melanoma': ['leukocyte A recombinant interferon ( rIFN-alpha'],
#  'advanced stage ( TNM IIB-IVB ) mycosis fungoides': ['a combination chemotherapy bleomycin and methotrexate weekly , doxorubicin every'],
#  'ventricular tachycardia': ['Guiding surgical therapy'],
#  'spinal adhesive arachnoiditis': ['Surgical management'],
#  'bronchiectasis': ['antibiotics and surgery', 'Current surgical therapy'],
#  'biliary dyskinesia': ['Cholecystectomy first-line therapy'],
#  'the common cold': ['pseudoephedrine plus acetaminophen'],
#  'symptoms of a common cold': ['Macrolide antibiotics'],
#  'rhinovirus': ['clarithromycin'],
#  'infection': ['a combination of omeprazole , amoxicillin , and clarithromycin'],
#  'persistent asthma': ['Contemporary asthma management guidelines list inhaled corticosteroids'],
#  'asthma': ['Fluticasone propionate several inhaled corticosteroids'],
#  'chronic hepatitis C': ['Combination therapy with interferon-alpha ( IFN alpha ) plus Ribavirin'],
#  'hepatitis C viremia': ['combination therapy'],
#  'severe hypoxemia': ['glucocorticoid pulse therapy'],
#  'primary sclerosing cholangitis ( PSC )': ['oral budesonide'],
#  'acute myocardial infarction': ['Thrombolytic therapy'],
#  'acute occlusion high-grade stenosis': ['thrombolytic therapy middle cerebral artery when early CT findings and/or lenticulostriate artery'],
#  'benign prostatic hyperplasia': ['conservative pharmacological treatment'],
#  'autoimmune diseases': ['High-dose intravenous immunoglobulin ( hdIVIg )'],
#  'phaeochromocytoma': ['Adrenalectomy'],
#  'malignant melanoma': ['interferon alfa-2a'],
#  'advanced renal cell carcinoma': ['various interferon alpha preparations interferon alfa-N1 , interferon alfa-2a , and interferon alfa-2b'],
#  'hairy cell leukemia infection': ['antileukemic therapy'],
#  "low-grade non-Hodgkin 's lymphoma": ['interferon alpha'],
#  'partial seizures': ['lamotrigine ( LTG )', 'lamotrigine monotherapy'],
#  'esophageal achalasia': ['botulinum toxin injection , pneumatic dilation , and laparoscopic myotomy'],
#  'prostate cancer': ['radical prostatectomy and iodine 125 interstitial radiotherapy'],
#  'mitomycin-resistant bladder cancer': ['photodynamic therapy in combination with mitomycin C'],
#  'B16 melanoma': ['adenosine triphosphate and treatment with buthionine sulfoximine'],
#  'primary uveal melanoma': ['transpupillary thermotherapy'],
#  'acute cerebral ischemia': ['Antiplatelet therapy'],
#  'renal cell carcinoma': ['Interferon treatment'],
#  'myocardial angiogenesis': ['Gene therapy'],
#  'autoimmune hemolytic anemia': ['heparin'],
#  'epithelial ovarian cancer': ['chemotherapy', 'High-dose chemotherapy'],
#  'moderately symptomatic benign prostatic hyperplasia': ['surgical resection'],
#  'multiple sclerosis': ['Interferon beta treatment',
#   'Intravenous immunoglobulin treatment'],
#  'acoustic neuroma': ['Stereotactic radiosurgery'],
#  'cerebral palsy': ['Hyperbaric oxygen therapy'],
#  'postvitrectomy diabetic vitreous hemorrhage': ['Peripheral retinal cryotherapy'],
#  'hepatitis B': ['vaccine'],
#  'temporomandibular joint arthropathy': ['arthroscopic treatment'],
#  'severe secondary peritonitis': ['Surgical management'],
#  'hepatic metastases from colorectal cancer': ['Hepatic arterial infusion of chemotherapy after resection'],
#  'chronic renal failure': ['Epoetin']}

# %% [markdown]
# ### Predict the treatment for the disease name: 'hereditary retinoblastoma'

# %%
# predicting the medication for 'hereditary retinoblastoma'
medication_data.get('hereditary retinoblastoma')
# Out:
# ['radiotherapy']

# %% [markdown]
# - radiotherepy is the treatment for 'hereditary retinoblastoma'
